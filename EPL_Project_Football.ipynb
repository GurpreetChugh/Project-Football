# %%
# Import Dependencies
import pandas as pd
import numpy as np

# %%
# Get summary tables for each of the last 5 seasons
table = pd.read_html('https://fbref.com/en/comps/9/2017-2018/2017-2018-Premier-League-Stats')
EPL_2018_summary_df = pd.DataFrame(table[0])

# %%
# Get summary tables for each of the last 5 seasons
table_1 = pd.read_html('https://fbref.com/en/comps/9/2018-2019/2018-2019-Premier-League-Stats')
EPL_2019_summary_df = pd.DataFrame(table_1[0])

# %%
# Get summary tables for each of the last 5 seasons
table_2 = pd.read_html('https://fbref.com/en/comps/9/2019-2020/2019-2020-Premier-League-Stats')
EPL_2020_summary_df = pd.DataFrame(table_2[0])

# %%
# Get summary tables for each of the last 5 seasons
table_3 = pd.read_html('https://fbref.com/en/comps/9/2020-2021/2020-2021-Premier-League-Stats')
EPL_2021_summary_df = pd.DataFrame(table_3[0])

# %%
# Get summary tables for each of the last 5 seasons
table_4 = pd.read_html('https://fbref.com/en/comps/9/2021-2022/2021-2022-Premier-League-Stats')
EPL_2022_summary_df = pd.DataFrame(table_4[0])

# %%
# Get wages table for each of the last 5 seasons
EPL_wages_2018_table = pd.read_html('https://fbref.com/en/comps/9/2017-2018/wages/2017-2018-Premier-League-Wages')
EPL_2018_wages_df = pd.DataFrame(EPL_wages_2018_table[0])

# %%
# Get wages table for each of the last 5 seasons
EPL_wages_2019_table = pd.read_html('https://fbref.com/en/comps/9/2018-2019/wages/2018-2019-Premier-League-Wages')
EPL_2019_wages_df = pd.DataFrame(EPL_wages_2019_table[0])

# %%
# Get wages table for each of the last 5 seasons
EPL_wages_2020_table = pd.read_html('https://fbref.com/en/comps/9/2019-2020/wages/2019-2020-Premier-League-Wages')
EPL_2020_wages_df = pd.DataFrame(EPL_wages_2020_table[0])

# %%
# Get wages table for each of the last 5 seasons
EPL_wages_2021_table = pd.read_html('https://fbref.com/en/comps/9/2020-2021/wages/2020-2021-Premier-League-Wages')
EPL_2021_wages_df = pd.DataFrame(EPL_wages_2021_table[0])

# %%
# Get wages table for each of the last 5 seasons
EPL_wages_2022_table = pd.read_html('https://fbref.com/en/comps/9/2021-2022/wages/2021-2022-Premier-League-Wages')
EPL_2022_wages_df = pd.DataFrame(EPL_wages_2022_table[0])

# %%
# Merge wages and season summary for each season
EPL_2018_merged_df = pd.merge(EPL_2018_wages_df, EPL_2018_summary_df, how="left", on=['Squad'])
EPL_2018_merged_df.head()
# Out:
#    Rk_x            Squad  # Pl                           Weekly Wages  \
# 0     1   Manchester Utd    35  £ 3,195,596 (€ 3,810,955, $3,883,356)
# 1     2          Arsenal    45  £ 3,043,385 (€ 3,629,433, $3,698,385)
# 2     3  Manchester City    32  £ 2,913,423 (€ 3,474,446, $3,540,453)
# 3     4          Chelsea    45  £ 2,339,654 (€ 2,790,189, $2,843,197)
# 4     5        Liverpool    34  £ 1,839,865 (€ 2,194,158, $2,235,843)
#
#                                   Annual Wages % Estimated  Rk_y  MP   W   D  \
# 0  £ 166,171,000 (€ 198,169,670, $201,934,520)        100%     2  38  25   6
# 1  £ 158,256,000 (€ 188,730,521, $192,316,043)        100%     6  38  19   6
# 2  £ 151,498,000 (€ 180,671,167, $184,103,578)        100%     1  38  32   4
# 3  £ 121,662,000 (€ 145,089,806, $147,846,240)        100%     5  38  21   7
# 4   £ 95,673,000 (€ 114,096,241, $116,263,857)        100%     4  38  21  12
#
#    ...  Pts  Pts/MP    xG   xGA   xGD  xGD/90  Attendance  \
# ...

# %%
# Merge wages and season summary for each season
EPL_2019_merged_df = pd.merge(EPL_2019_wages_df, EPL_2019_summary_df, how="left", on=['Squad'])
EPL_2019_merged_df.head()
# Out:
#    Rk_x            Squad  # Pl                           Weekly Wages  \
# 0     1          Chelsea   102  £ 3,028,981 (€ 3,612,255, $3,680,882)
# 1     2   Manchester Utd    86  £ 2,910,096 (€ 3,470,478, $3,536,411)
# 2     3  Manchester City    96  £ 2,896,365 (€ 3,454,103, $3,519,725)
# 3     4          Arsenal    91  £ 2,603,077 (€ 3,104,338, $3,163,314)
# 4     5        Liverpool    88  £ 2,451,154 (€ 2,923,160, $2,978,694)
#
#                                   Annual Wages % Estimated  Rk_y  MP   W  D  \
# 0  £ 157,507,000 (€ 187,837,283, $191,405,844)        100%     3  38  21  9
# 1  £ 151,325,000 (€ 180,464,856, $183,893,347)        100%     6  38  19  9
# 2  £ 150,611,000 (€ 179,613,362, $183,025,676)        100%     1  38  32  2
# 3  £ 135,360,000 (€ 161,425,557, $164,492,342)        100%     5  38  21  7
# 4  £ 127,460,000 (€ 152,004,295, $154,892,092)        100%     2  38  30  7
#
#    ...  Pts  Pts/MP    xG   xGA   xGD  xGD/90  Attendance  \
# ...

# %%
# Merge wages and season summary for each season
EPL_2020_merged_df = pd.merge(EPL_2020_wages_df, EPL_2020_summary_df, how="left", on=['Squad'])
EPL_2020_merged_df.head()
# Out:
#    Rk_x            Squad  # Pl                           Weekly Wages  \
# 0     1   Manchester Utd    78  £ 3,181,538 (€ 3,794,190, $3,866,273)
# 1     2  Manchester City    71  £ 2,865,192 (€ 3,416,927, $3,481,842)
# 2     3          Chelsea    79  £ 2,300,962 (€ 2,744,046, $2,796,177)
# 3     4          Arsenal    78  £ 2,279,615 (€ 2,718,589, $2,770,237)
# 4     5        Liverpool    70  £ 2,209,038 (€ 2,634,421, $2,684,470)
#
#                                   Annual Wages % Estimated  Rk_y  MP   W   D  \
# 0  £ 165,440,000 (€ 197,297,905, $201,046,193)         33%     3  38  18  12
# 1  £ 148,990,000 (€ 177,680,216, $181,055,805)         31%     2  38  26   3
# 2  £ 119,650,000 (€ 142,690,368, $145,401,216)         35%     4  38  20   6
# 3  £ 118,540,000 (€ 141,366,618, $144,052,322)         32%     8  38  14  14
# 4  £ 114,870,000 (€ 136,989,906, $139,592,457)         31%     1  38  32   3
#
#    ...  Pts  Pts/MP    xG   xGA   xGD  xGD/90  Attendance  \
# ...

# %%
# Merge wages and season summary for each season
EPL_2021_merged_df = pd.merge(EPL_2021_wages_df, EPL_2021_summary_df, how="left", on=['Squad'])
EPL_2021_merged_df.head()
# Out:
#    Rk_x            Squad  # Pl                           Weekly Wages  \
# 0     1   Manchester Utd    86  £ 3,719,423 (€ 4,435,653, $4,519,922)
# 1     2          Chelsea    82  £ 2,842,538 (€ 3,389,911, $3,454,313)
# 2     3          Arsenal    87  £ 2,835,577 (€ 3,381,609, $3,445,853)
# 3     4  Manchester City    76  £ 2,647,654 (€ 3,157,499, $3,217,485)
# 4     5        Tottenham    82  £ 2,586,077 (€ 3,084,064, $3,142,655)
#
#                                   Annual Wages % Estimated  Rk_y  MP   W   D  \
# 0  £ 193,410,000 (€ 230,653,939, $235,035,931)          3%     2  38  21  11
# 1  £ 147,811,988 (€ 176,275,358, $179,624,258)          2%     4  38  19  10
# 2  £ 147,450,000 (€ 175,843,663, $179,184,367)          1%     8  38  18   7
# 3  £ 137,678,000 (€ 164,189,924, $167,309,223)          1%     1  38  27   5
# 4  £ 134,476,000 (€ 160,371,329, $163,418,084)          4%     7  38  18   8
#
#    ...  Pts  Pts/MP    xG   xGA   xGD  xGD/90  Attendance  \
# ...

# %%
# Merge wages and season summary for each season
EPL_2022_merged_df = pd.merge(EPL_2022_wages_df, EPL_2022_summary_df, how="left", on=['Squad'])
EPL_2022_merged_df.head()
# Out:
#    Rk_x            Squad  # Pl                           Weekly Wages  \
# 0     1   Manchester Utd    82  £ 4,593,269 (€ 5,477,771, $5,581,838)
# 1     2          Chelsea    81  £ 3,382,500 (€ 4,033,850, $4,110,486)
# 2     3  Manchester City    67  £ 2,914,462 (€ 3,475,684, $3,541,715)
# 3     4        Liverpool    83  £ 2,777,154 (€ 3,311,936, $3,374,856)
# 4     5          Arsenal    70  £ 2,199,423 (€ 2,622,954, $2,672,786)
#
#                                   Annual Wages % Estimated  Rk_y  MP   W   D  \
# 0  £ 238,850,000 (€ 284,844,078, $290,255,583)          5%     6  38  16  10
# 1  £ 175,890,000 (€ 209,760,207, $213,745,254)          2%     3  38  21  11
# 2  £ 151,552,000 (€ 180,735,566, $184,169,203)          8%     1  38  29   6
# 3  £ 144,412,000 (€ 172,220,653, $175,492,521)          6%     2  38  28   8
# 4  £ 114,370,000 (€ 136,393,624, $138,984,848)          6%     5  38  22   3
#
#    ...  Pts  Pts/MP    xG   xGA   xGD  xGD/90  Attendance  \
# ...

# %%
# Select desired columns for final summary table
EPL_2018_merged_df.columns
# Out:
# Index(['Rk_x', 'Squad', '# Pl', 'Weekly Wages', 'Annual Wages', '% Estimated',
#        'Rk_y', 'MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Pts/MP', 'xG',
#        'xGA', 'xGD', 'xGD/90', 'Attendance', 'Top Team Scorer', 'Goalkeeper',
#        'Notes'],
#       dtype='object')

# %%
# Select desired columns for final summary table
EPL_2018_summary_complete_df = EPL_2018_merged_df[['Rk_y', 'Squad', 'Annual Wages','MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 
                                                   'Pts/MP', 'xG', 'xGA', 'xGD', 'xGD/90', 'Attendance']]
EPL_2018_summary_complete_df.head()
# Out:
#    Rk_y            Squad                                 Annual Wages  MP   W  \
# 0     2   Manchester Utd  £ 166,171,000 (€ 198,169,670, $201,934,520)  38  25
# 1     6          Arsenal  £ 158,256,000 (€ 188,730,521, $192,316,043)  38  19
# 2     1  Manchester City  £ 151,498,000 (€ 180,671,167, $184,103,578)  38  32
# 3     5          Chelsea  £ 121,662,000 (€ 145,089,806, $147,846,240)  38  21
# 4     4        Liverpool   £ 95,673,000 (€ 114,096,241, $116,263,857)  38  21
#
#     D   L   GF  GA  GD  Pts  Pts/MP    xG   xGA   xGD  xGD/90  Attendance
# 0   6   7   68  28  40   81    2.13  55.7  40.7  15.0    0.40       74976
# 1   6  13   74  51  23   63    1.66  68.3  47.8  20.5    0.54       59323
# 2   4   2  106  27  79  100    2.63  78.6  23.8  54.8    1.44       54070
# 3   7  10   62  38  24   70    1.84  54.4  33.8  20.6    0.54       41282
# 4  12   5   84  38  46   75    1.97  72.9  33.8  39.1    1.03       53049

# %%
# Rename columns
EPL_2018_summary_complete_df = EPL_2018_summary_complete_df.rename(columns={ 'Rk_y': 'League Rank'})
EPL_2018_summary_complete_df.head()
# Out:
#    League Rank            Squad                                 Annual Wages  \
# 0            2   Manchester Utd  £ 166,171,000 (€ 198,169,670, $201,934,520)
# 1            6          Arsenal  £ 158,256,000 (€ 188,730,521, $192,316,043)
# 2            1  Manchester City  £ 151,498,000 (€ 180,671,167, $184,103,578)
# 3            5          Chelsea  £ 121,662,000 (€ 145,089,806, $147,846,240)
# 4            4        Liverpool   £ 95,673,000 (€ 114,096,241, $116,263,857)
#
#    MP   W   D   L   GF  GA  GD  Pts  Pts/MP    xG   xGA   xGD  xGD/90  \
# 0  38  25   6   7   68  28  40   81    2.13  55.7  40.7  15.0    0.40
# 1  38  19   6  13   74  51  23   63    1.66  68.3  47.8  20.5    0.54
# 2  38  32   4   2  106  27  79  100    2.63  78.6  23.8  54.8    1.44
# 3  38  21   7  10   62  38  24   70    1.84  54.4  33.8  20.6    0.54
# 4  38  21  12   5   84  38  46   75    1.97  72.9  33.8  39.1    1.03
#
#    Attendance
# 0       74976
# 1       59323
# 2       54070
# 3       41282
# ...

# %%
# Sort by league position
EPL_2018_summary_complete_df.sort_values('Pts', ascending=False)
# Out:
#     League Rank            Squad                                 Annual Wages  \
# 2             1  Manchester City  £ 151,498,000 (€ 180,671,167, $184,103,578)
# 0             2   Manchester Utd  £ 166,171,000 (€ 198,169,670, $201,934,520)
# 6             3        Tottenham     £ 80,298,000 (€ 95,760,561, $97,579,832)
# 4             4        Liverpool   £ 95,673,000 (€ 114,096,241, $116,263,857)
# 3             5          Chelsea  £ 121,662,000 (€ 145,089,806, $147,846,240)
# 1             6          Arsenal  £ 158,256,000 (€ 188,730,521, $192,316,043)
# 18            7          Burnley     £ 32,557,000 (€ 38,826,329, $39,563,962)
# 5             8          Everton   £ 85,440,000 (€ 101,892,731, $103,828,499)
# 10            9   Leicester City     £ 64,107,000 (€ 76,451,744, $77,904,185)
# 9            11   Crystal Palace     £ 68,041,000 (€ 81,143,294, $82,684,869)
# 15           12      Bournemouth     £ 43,061,000 (€ 51,353,032, $52,328,645)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12448\2608017670.py in <module>
# ----> 1 EPL_2018_summary_complete_df[['Annual Wages (pounds)', 'Annual Wages (euros)', 'Annual Wages ($)']] = EPL_2018_summary_complete_df['Annual Wages'].str.split(expand=True)
#       2 EPL_2018_summary_complete_df.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3641             self._setitem_frame(key, value)
#    3642         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3643             self._setitem_array(key, value)
#    3644         elif isinstance(value, DataFrame):
#    3645             self._set_item_frame_value(key, value)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    3683
#    3684             if isinstance(value, DataFrame):
# ...
