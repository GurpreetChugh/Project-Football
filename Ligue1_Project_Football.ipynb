# %%
# Import Dependencies
import pandas as pd
import numpy as np

# %%
# Get urls for all seasons, wages and fixtures
seasons = ['https://fbref.com/en/comps/13/2017-2018/2017-2018-Ligue-1-Stats',
           'https://fbref.com/en/comps/13/2018-2019/2018-2019-Ligue-1-Stats',
           'https://fbref.com/en/comps/13/2019-2020/2019-2020-Ligue-1-Stats',
           'https://fbref.com/en/comps/13/2020-2021/2020-2021-Ligue-1-Stats',
           'https://fbref.com/en/comps/13/2021-2022/2021-2022-Ligue-1-Stats',
           'https://fbref.com/en/comps/13/2022-2023/2022-2023-Ligue-1-Stats'
          ]
wages = ['https://fbref.com/en/comps/13/2017-2018/wages/2017-2018-Ligue-1-Wages',
         'https://fbref.com/en/comps/13/2018-2019/wages/2018-2019-Ligue-1-Wages',
         'https://fbref.com/en/comps/13/2019-2020/wages/2019-2020-Ligue-1-Wages',
         'https://fbref.com/en/comps/13/2020-2021/wages/2020-2021-Ligue-1-Wages',
         'https://fbref.com/en/comps/13/2021-2022/wages/2021-2022-Ligue-1-Wages',
         'https://fbref.com/en/comps/13/2022-2023/wages/2022-2023-Ligue-1-Wages'
        ]
fixtures = ['https://fbref.com/en/comps/13/2017-2018/schedule/2017-2018-Ligue-1-Scores-and-Fixtures',
            'https://fbref.com/en/comps/13/2018-2019/schedule/2018-2019-Ligue-1-Scores-and-Fixtures',
            'https://fbref.com/en/comps/13/2019-2020/schedule/2019-2020-Ligue-1-Scores-and-Fixtures',
            'https://fbref.com/en/comps/13/2020-2021/schedule/2020-2021-Ligue-1-Scores-and-Fixtures',
            'https://fbref.com/en/comps/13/2021-2022/schedule/2021-2022-Ligue-1-Scores-and-Fixtures',
            'https://fbref.com/en/comps/13/2022-2023/schedule/2022-2023-Ligue-1-Scores-and-Fixtures'
    
    
]

url = seasons[0]
table = pd.read_html(url)
Ligue1_2018_summary_df = pd.DataFrame(table[0])
url = seasons[1]
table = pd.read_html(url)
Ligue1_2019_summary_df = pd.DataFrame(table[0])
url = seasons[2]
table = pd.read_html(url)
Ligue1_2020_summary_df = pd.DataFrame(table[0])
url = seasons[3]
table = pd.read_html(url)
Ligue1_2020_summary_df = pd.DataFrame(table[0])
url = seasons[4]
table = pd.read_html(url)
Ligue1_2021_summary_df = pd.DataFrame(table[0])
url = seasons[5]
table = pd.read_html(url)
Ligue1_2022_summary_df = pd.DataFrame(table[0])
Ligue1_2018_summary_df['Season'] = '2017-2018'
Ligue1_2019_summary_df['Season'] = '2018-2019'
Ligue1_2020_summary_df['Season'] = '2019-2020'
Ligue1_2021_summary_df['Season'] = '2020-2021'
Ligue1_2022_summary_df['Season'] = '2021-2022'

Ligue1_2018_summary_df.head()
# Out:
#    Rk      Squad  MP   W   D   L   GF  GA  GD  Pts  Pts/MP    xG   xGA   xGD  \
# 0   1  Paris S-G  38  29   6   3  108  29  79   93    2.45  86.1  34.3  51.7
# 1   2     Monaco  38  24   8   6   85  45  40   80    2.11  62.3  48.5  13.8
# 2   3       Lyon  38  23   9   6   87  43  44   78    2.05  63.4  40.1  23.3
# 3   4  Marseille  38  22  11   5   80  47  33   77    2.03  78.1  41.8  36.3
# 4   5     Rennes  38  16  10  12   50  44   6   58    1.53  49.8  49.3   0.5
#
#    xGD/90  Attendance           Top Team Scorer       Goalkeeper  \
# 0    1.36       46930       Edinson Cavani - 28  Alphonse Areola
# 1    0.36        9243       Radamel Falcao - 18  Danijel Subašić
# 2    0.61       44047              Memphis - 19    Anthony Lopes
# 3    0.96       46616      Florian Thauvin - 22   Steve Mandanda
# 4    0.01       23111  Benjamin Bourigeaud - 10     Tomáš Koubek
#
#                                   Notes     Season
# 0  → Champions League via league finish  2017-2018
# ...

# %%
# Get 2nd summary table (index[2])for each season
url = seasons[0]
table = pd.read_html(url)
Ligue1_2018_summary2_df = pd.DataFrame(table[2])
url = seasons[1]
table = pd.read_html(url)
Ligue1_2019_summary2_df = pd.DataFrame(table[2])
url = seasons[2]
table = pd.read_html(url)
Ligue1_2020_summary2_df = pd.DataFrame(table[2])
url = seasons[3]
table = pd.read_html(url)
Ligue1_2020_summary2_df = pd.DataFrame(table[2])
url = seasons[4]
table = pd.read_html(url)
Ligue1_2021_summary2_df = pd.DataFrame(table[2])
url = seasons[5]
table = pd.read_html(url)
Ligue1_2022_summary2_df = pd.DataFrame(table[2])
# Remove upper level to allow for merging with other tables
Ligue1_2018_summary2_df = Ligue1_2018_summary2_df.droplevel(0, axis = 1)
Ligue1_2019_summary2_df = Ligue1_2019_summary2_df.droplevel(0, axis = 1)
Ligue1_2020_summary2_df = Ligue1_2020_summary2_df.droplevel(0, axis = 1)
Ligue1_2021_summary2_df = Ligue1_2021_summary2_df.droplevel(0, axis = 1)
Ligue1_2022_summary2_df = Ligue1_2022_summary2_df.droplevel(0, axis = 1)

Ligue1_2018_summary2_df['Season'] = '2017-2018'
Ligue1_2019_summary2_df['Season'] = '2018-2019'
Ligue1_2020_summary2_df['Season'] = '2019-2020'
Ligue1_2021_summary2_df['Season'] = '2020-2021'
Ligue1_2022_summary2_df['Season'] = '2021-2022'

Ligue1_2022_summary2_df
# Out:
#             Squad  # Pl   Age  Poss  MP  Starts   Min   90s  Gls  Ast  ...  \
# 0         Ajaccio    33  30.0  45.3  30     330  2700  30.0   20   11  ...
# 1          Angers    33  26.6  46.6  30     330  2700  30.0   21   12  ...
# 2         Auxerre    32  28.2  44.1  30     330  2700  30.0   24   16  ...
# 3           Brest    29  27.3  43.9  30     330  2700  30.0   33   22  ...
# 4   Clermont Foot    27  27.8  48.8  30     330  2700  30.0   30   18  ...
# 5            Lens    28  27.0  56.5  30     330  2700  30.0   48   36  ...
# 6           Lille    25  26.7  59.6  30     330  2700  30.0   54   34  ...
# 7         Lorient    28  25.9  45.3  30     330  2700  30.0   39   26  ...
# 8            Lyon    28  26.3  58.0  30     330  2700  30.0   47   34  ...
# 9       Marseille    29  27.9  55.6  30     330  2700  30.0   49   30  ...
# 10         Monaco    27  25.4  49.1  30     330  2700  30.0   62   43  ...
# ...

# %%
# Remove upper level to allow for merging with other tables
#Ligue1_2018_summary2_df = Ligue1_2018_summary2_df.droplevel(0, axis = 1)
#Ligue1_2019_summary2_df = Ligue1_2019_summary2_df.droplevel(0, axis = 1)
#Ligue1_2020_summary2_df = Ligue1_2020_summary2_df.droplevel(0, axis = 1)
#Ligue1_2021_summary2_df = Ligue1_2021_summary2_df.droplevel(0, axis = 1)
#Ligue1_2022_summary2_df = Ligue1_2022_summary2_df.droplevel(0, axis = 1)

# %%
# Get wages table for each of the last 5 seasons
url = wages[0]
table = pd.read_html(url)
Ligue1_2018_wages_df = pd.DataFrame(table[0])
url = wages[1]
table = pd.read_html(url)
Ligue1_2019_wages_df = pd.DataFrame(table[0])
url = wages[2]
table = pd.read_html(url)
Ligue1_2020_wages_df = pd.DataFrame(table[0])
url = wages[3]
table = pd.read_html(url)
Ligue1_2020_wages_df = pd.DataFrame(table[0])

url = wages[4]
table = pd.read_html(url)
Ligue1_2021_wages_df = pd.DataFrame(table[0])

url = wages[5]
table = pd.read_html(url)
Ligue1_2022_wages_df = pd.DataFrame(table[0])

Ligue1_2018_wages_df['Season'] = '2017-2018'
Ligue1_2019_wages_df['Season'] = '2018-2019'
Ligue1_2020_wages_df['Season'] = '2019-2020'
Ligue1_2021_wages_df['Season'] = '2020-2021'
Ligue1_2022_wages_df['Season'] = '2021-2022'
Ligue1_2021_wages_df
# Out:
#     Rk          Squad  # Pl                           Weekly Wages  \
# 0    1      Paris S-G   108  € 8,321,154 (£ 6,977,357, $8,480,185)
# 1    2           Lyon    88  € 1,314,423 (£ 1,102,155, $1,339,544)
# 2    3      Marseille    89    € 1,071,346 (£ 898,333, $1,091,821)
# 3    4         Monaco    88    € 1,016,154 (£ 852,053, $1,035,574)
# 4    5           Nice    82        € 559,615 (£ 469,242, $570,311)
# 5    6          Lille    77        € 540,385 (£ 453,117, $550,712)
# 6    7       Bordeaux    93        € 532,115 (£ 446,183, $542,285)
# 7    8         Rennes    83        € 460,000 (£ 385,714, $468,791)
# 8    9  Saint-Étienne    91        € 390,962 (£ 327,825, $398,434)
# 9   10         Nantes    84        € 365,192 (£ 306,217, $372,172)
# 10  11     Strasbourg    77        € 265,962 (£ 223,011, $271,045)
# 11  12    Montpellier    75        € 236,923 (£ 198,662, $241,451)
# 12  13         Angers    81        € 233,654 (£ 195,921, $238,119)
# ...

# %%
# Merge wages and season summary for each season
Ligue1_2018_merged_df = pd.merge(Ligue1_2018_summary_df, Ligue1_2018_wages_df, how="left", on=['Squad','Season'])
Ligue1_2019_merged_df = pd.merge(Ligue1_2019_summary_df, Ligue1_2019_wages_df, how="left", on=['Squad','Season'])
Ligue1_2020_merged_df = pd.merge(Ligue1_2020_summary_df, Ligue1_2020_wages_df, how="left", on=['Squad','Season'])                                                                                         
Ligue1_2021_merged_df = pd.merge(Ligue1_2021_summary_df, Ligue1_2021_wages_df, how="left", on=['Squad','Season'])
Ligue1_2022_merged_df = pd.merge(Ligue1_2022_summary_df, Ligue1_2022_wages_df, how="left", on=['Squad','Season'])

Ligue1_all_wages_df = pd.concat([Ligue1_2018_merged_df,Ligue1_2019_merged_df, Ligue1_2020_merged_df,
                               Ligue1_2021_merged_df, Ligue1_2022_merged_df], axis=0)
# Out:
#     Rk_x          Squad  MP   W   D   L   GF  GA  GD  Pts  ...  \
# 0      1      Paris S-G  38  29   6   3  108  29  79   93  ...
# 1      2         Monaco  38  24   8   6   85  45  40   80  ...
# 2      3           Lyon  38  23   9   6   87  43  44   78  ...
# 3      4      Marseille  38  22  11   5   80  47  33   77  ...
# 4      5         Rennes  38  16  10  12   50  44   6   58  ...
# 5      6       Bordeaux  38  16   7  15   53  48   5   55  ...
# 6      7  Saint-Étienne  38  15  10  13   47  50  -3   55  ...
# 7      8           Nice  38  15   9  14   53  52   1   54  ...
# 8      9         Nantes  38  14  10  14   36  41  -5   52  ...
# 9     10    Montpellier  38  11  18   9   36  33   3   51  ...
# 10    11          Dijon  38  13   9  16   55  73 -18   48  ...
# 11    12       Guingamp  38  12  11  15   48  59 -11   47  ...
# 12    13         Amiens  38  12   9  17   37  42  -5   45  ...
# 13    14         Angers  38   9  14  15   42  52 -10   41  ...
# ...

# %%
Ligue1_all_wages_df.columns
# Out:
# Index(['Rk_x', 'Squad', 'MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Pts/MP',
#        'xG', 'xGA', 'xGD', 'xGD/90', 'Attendance', 'Top Team Scorer',
#        'Goalkeeper', 'Notes', 'Season', 'Rk_y', '# Pl', 'Weekly Wages',
#        'Annual Wages', '% Estimated', 'Last 5'],
#       dtype='object')

# %%
# Merge in summary table#2 for each season
Ligue1_2018_complete_df = pd.merge(Ligue1_2018_merged_df, Ligue1_2018_summary2_df, how="left", on=['Squad','Season'])
#Ligue1_2018_complete_df.head(15)
Ligue1_2019_complete_df = pd.merge(Ligue1_2019_merged_df, Ligue1_2019_summary2_df, how="left", on=['Squad','Season'])
Ligue1_2020_complete_df = pd.merge(Ligue1_2020_merged_df, Ligue1_2020_summary2_df, how="left", on=['Squad','Season'])
Ligue1_2021_complete_df = pd.merge(Ligue1_2021_merged_df, Ligue1_2021_summary2_df, how="left", on=['Squad','Season'])
Ligue1_2022_complete_df = pd.merge(Ligue1_2022_merged_df, Ligue1_2022_summary2_df, how="left", on=['Squad','Season'])

# %%
#Ligue1_all_seasons_df.rename(columns={ 'xG': 'xG Home', 'xG.1': 'xG Away'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5560\3639220725.py in <module>
# ----> 1 Ligue1_all_seasons_df.rename(columns={ 'xG': 'xG Home', 'xG.1': 'xG Away'})
#
# NameError: name 'Ligue1_all_seasons_df' is not defined

# %%
# Select desired columns for final summary table
Ligue1_2018_sum_complete_df = Ligue1_2018_complete_df[['Rk_y', 'Squad','# Pl_x', 'Age', 'Poss', 'Annual Wages','MP_x', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 
                                                   'Pts/MP', 'xG_x', 'xGA', 'xGD', 'xGD/90', 'Attendance','Season']]
Ligue1_2019_sum_complete_df = Ligue1_2019_complete_df[['Rk_y', 'Squad','# Pl_x', 'Age', 'Poss', 'Annual Wages','MP_x', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 
                                                   'Pts/MP', 'xG_x', 'xGA', 'xGD', 'xGD/90', 'Attendance','Season']]
Ligue1_2020_sum_complete_df = Ligue1_2020_complete_df[['Rk_y', 'Squad','# Pl_x', 'Age', 'Poss', 'Annual Wages','MP_x', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 
                                                   'Pts/MP', 'xG_x', 'xGA', 'xGD', 'xGD/90', 'Attendance','Season']]
Ligue1_2021_sum_complete_df = Ligue1_2021_complete_df[['Rk_y', 'Squad','# Pl_x', 'Age', 'Poss', 'Annual Wages','MP_x', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 
                                                   'Pts/MP', 'xG_x', 'xGA', 'xGD', 'xGD/90', 'Attendance','Season']]
Ligue1_2022_sum_complete_df = Ligue1_2022_complete_df[['Rk_y', 'Squad','# Pl_x', 'Age', 'Poss', 'Annual Wages','MP_x', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 
                                                   'Pts/MP', 'xG_x', 'xGA', 'xGD', 'xGD/90', 'Attendance','Season']]

# %%
Ligue1_2022_sum_complete_df
# Out:
#     Rk_y          Squad  # Pl_x   Age  Poss  \
# 0      1      Paris S-G      32  27.5  60.3
# 1     13           Lens      25  27.0  56.5
# 2      2      Marseille      28  27.9  55.6
# 3      3         Monaco      28  25.4  49.1
# 4      6          Lille      25  26.7  59.6
# 5      7         Rennes      28  25.9  54.7
# 6      4           Lyon      27  26.3  58.0
# 7     10          Reims      27  25.6  47.1
# 8      5           Nice      27  27.4  51.2
# 9     16        Lorient      25  25.9  45.3
# 10    19  Clermont Foot      26  27.8  48.8
# 11    15       Toulouse      26  25.9  51.0
# 12    11    Montpellier      27  26.6  46.8
# 13     8         Nantes      27  27.5  46.0
# 14    18        Auxerre      33  28.2  44.1
# 15    14          Brest      25  27.3  43.9
# 16     9     Strasbourg      26  28.3  46.7
# 17    17         Troyes      28  26.7  43.8
# 18    20        Ajaccio      31  30.0  45.3
# 19    12         Angers      34  26.6  46.6
#
# ...

# %%
# Rename columns
Ligue1_2018_sum_complete_df = Ligue1_2018_sum_complete_df.rename(columns={ 'Rk_y': 'League Rank', 'Age': 'Avg Age', 
                                                                    'Poss': 'Avg Poss', 
                                                                    '# Pl_x': '# of Players', 'MP_x': 'MP', 
                                                                    'xG_x': 'xG'})
Ligue1_2019_sum_complete_df = Ligue1_2019_sum_complete_df.rename(columns={ 'Rk_y': 'League Rank', 'Age': 'Avg Age', 
                                                                    'Poss': 'Avg Poss', 
                                                                    '# Pl_x': '# of Players', 'MP_x': 'MP', 
                                                                    'xG_x': 'xG'})
Ligue1_2020_sum_complete_df = Ligue1_2020_sum_complete_df.rename(columns={ 'Rk_y': 'League Rank', 'Age': 'Avg Age', 
                                                                    'Poss': 'Avg Poss', 
                                                                    '# Pl_x': '# of Players', 'MP_x': 'MP', 
                                                                    'xG_x': 'xG'})
Ligue1_2021_sum_complete_df = Ligue1_2021_sum_complete_df.rename(columns={ 'Rk_y': 'League Rank', 'Age': 'Avg Age', 
                                                                    'Poss': 'Avg Poss', 
                                                                    '# Pl_x': '# of Players', 'MP_x': 'MP', 
                                                                    'xG_x': 'xG'})
Ligue1_2022_sum_complete_df = Ligue1_2022_sum_complete_df.rename(columns={ 'Rk_y': 'League Rank', 'Age': 'Avg Age', 
                                                                    'Poss': 'Avg Poss', 
                                                                    '# Pl_x': '# of Players', 'MP_x': 'MP', 
                                                                    'xG_x': 'xG'})
Ligue1_2022_sum_complete_df.tail()
# Out:
#     League Rank       Squad  # of Players  Avg Age  Avg Poss  \
# 15           14       Brest            25     27.3      43.9
# 16            9  Strasbourg            26     28.3      46.7
# 17           17      Troyes            28     26.7      43.8
# 18           20     Ajaccio            31     30.0      45.3
# 19           12      Angers            34     26.6      46.6
#
#                                 Annual Wages  MP  W   D   L  ...  GA  GD  Pts  \
# 15     € 6,520,000 (£ 5,867,704, $6,273,807)  30  6  10  14  ...  48 -14   28
# 16  € 11,680,000 (£ 10,511,471, $11,238,970)  30  5  11  14  ...  52 -14   26
# 17     € 5,050,000 (£ 4,544,770, $4,859,314)  30  4   9  17  ...  64 -26   21
# 18     € 2,400,000 (£ 2,159,891, $2,309,378)  30  6   3  21  ...  55 -34   21
# 19     € 7,940,000 (£ 7,145,641, $7,640,191)  30  3   5  22  ...  64 -41   14
#
#     Pts/MP    xG   xGA   xGD  xGD/90  Attendance     Season
# 15    0.93  33.8  48.9 -15.0   -0.50       11239  2021-2022
# ...

# %%
# Convert 'Annual Wages' column into single column with only dollar value
Ligue1_2018_sum_complete_df[['pounds', 'dollars']] = Ligue1_2018_sum_complete_df['Annual Wages'].str.split('$', expand=True)
Ligue1_2019_sum_complete_df[['pounds', 'dollars']] = Ligue1_2019_sum_complete_df['Annual Wages'].str.split('$', expand=True)
Ligue1_2020_sum_complete_df[['pounds', 'dollars']] = Ligue1_2020_sum_complete_df['Annual Wages'].str.split('$', expand=True)
Ligue1_2021_sum_complete_df[['pounds', 'dollars']] = Ligue1_2021_sum_complete_df['Annual Wages'].str.split('$', expand=True)
Ligue1_2022_sum_complete_df[['pounds', 'dollars']] = Ligue1_2022_sum_complete_df['Annual Wages'].str.split('$', expand=True)
Ligue1_2022_sum_complete_df.columns
# Out:
# Index(['League Rank', 'Squad', '# of Players', 'Avg Age', 'Avg Poss',
#        'Annual Wages', 'MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Pts/MP',
#        'xG', 'xGA', 'xGD', 'xGD/90', 'Attendance', 'Season', 'pounds',
#        'dollars'],
#       dtype='object')

# %%
# Convert 'Annual Wages' column into single column with only dollar value
Ligue1_2018_sum_complete_df[['Annual Wages ($)', 'discard']] = Ligue1_2018_sum_complete_df['dollars'].str.split(')', expand=True)
Ligue1_2019_sum_complete_df[['Annual Wages ($)', 'discard']] = Ligue1_2019_sum_complete_df['dollars'].str.split(')', expand=True)
Ligue1_2020_sum_complete_df[['Annual Wages ($)', 'discard']] = Ligue1_2020_sum_complete_df['dollars'].str.split(')', expand=True)
Ligue1_2021_sum_complete_df[['Annual Wages ($)', 'discard']] = Ligue1_2021_sum_complete_df['dollars'].str.split(')', expand=True)
Ligue1_2022_sum_complete_df[['Annual Wages ($)', 'discard']] = Ligue1_2022_sum_complete_df['dollars'].str.split(')', expand=True)
Ligue1_2022_sum_complete_df.head()
# Out:
#    League Rank      Squad  # of Players  Avg Age  Avg Poss  \
# 0            1  Paris S-G            32     27.5      60.3
# 1           13       Lens            25     27.0      56.5
# 2            2  Marseille            28     27.9      55.6
# 3            3     Monaco            28     25.4      49.1
# 4            6      Lille            25     26.7      59.6
#
#                                   Annual Wages  MP   W  D  L  ...    xG   xGA  \
# 0  € 386,840,000 (£ 348,138,457, $372,233,147)  30  22  3  5  ...  62.0  35.5
# 1        € 7,300,000 (£ 6,569,670, $7,024,357)  30  18  9  3  ...  52.4  32.3
# 2     € 51,730,000 (£ 46,554,653, $49,776,705)  30  18  7  5  ...  49.8  36.6
# 3     € 46,000,000 (£ 41,397,917, $44,263,068)  30  17  7  6  ...  50.2  40.0
# 4     € 17,530,000 (£ 15,776,205, $16,868,075)  30  15  7  8  ...  54.9  33.4
#
#     xGD  xGD/90  Attendance     Season                          pounds  \
# ...

# %%
# Drop unwanted columns 
Ligue1_2018_sum_clean_df = Ligue1_2018_sum_complete_df.drop(['pounds', 'dollars', 'Annual Wages', 'discard'], axis=1)
Ligue1_2019_sum_clean_df = Ligue1_2019_sum_complete_df.drop(['pounds', 'dollars', 'Annual Wages', 'discard'], axis=1)
Ligue1_2020_sum_clean_df = Ligue1_2020_sum_complete_df.drop(['pounds', 'dollars', 'Annual Wages', 'discard'], axis=1)
Ligue1_2021_sum_clean_df = Ligue1_2021_sum_complete_df.drop(['pounds', 'dollars', 'Annual Wages', 'discard'], axis=1)
Ligue1_2022_sum_clean_df = Ligue1_2022_sum_complete_df.drop(['pounds', 'dollars', 'Annual Wages', 'discard'], axis=1)
Ligue1_2022_sum_clean_df.head()
# Out:
#    League Rank      Squad  # of Players  Avg Age  Avg Poss  MP   W  D  L  GF  \
# 0            1  Paris S-G            32     27.5      60.3  30  22  3  5  70
# 1           13       Lens            25     27.0      56.5  30  18  9  3  50
# 2            2  Marseille            28     27.9      55.6  30  18  7  5  54
# 3            3     Monaco            28     25.4      49.1  30  17  7  6  63
# 4            6      Lille            25     26.7      59.6  30  15  7  8  54
#
#    ...  GD  Pts  Pts/MP    xG   xGA   xGD  xGD/90  Attendance     Season  \
# 0  ...  41   69    2.30  62.0  35.5  26.5    0.88       40067  2021-2022
# 1  ...  28   63    2.10  52.4  32.3  20.1    0.67       37577  2021-2022
# 2  ...  25   61    2.03  49.8  36.6  13.2    0.44       62532  2021-2022
# 3  ...  21   58    1.93  50.2  40.0  10.1    0.34        6931  2021-2022
# 4  ...  16   52    1.73  54.9  33.4  21.5    0.72       33048  2021-2022
#
#   Annual Wages ($)
# 0      372,233,147
# 1        7,024,357
# ...

# %%
# Sort by league position
Ligue1_2018_sum_complete_df.sort_values('Pts', ascending=False)
Ligue1_2019_sum_complete_df.sort_values('Pts', ascending=False)
Ligue1_2020_sum_complete_df.sort_values('Pts', ascending=False)
Ligue1_2021_sum_complete_df.sort_values('Pts', ascending=False)
Ligue1_2022_sum_complete_df.sort_values('Pts', ascending=False)

Ligue1_2022_sum_complete_df
# Out:
#     League Rank          Squad  # of Players  Avg Age  Avg Poss  \
# 0             1      Paris S-G            32     27.5      60.3
# 1            13           Lens            25     27.0      56.5
# 2             2      Marseille            28     27.9      55.6
# 3             3         Monaco            28     25.4      49.1
# 4             6          Lille            25     26.7      59.6
# 5             7         Rennes            28     25.9      54.7
# 6             4           Lyon            27     26.3      58.0
# 7            10          Reims            27     25.6      47.1
# 8             5           Nice            27     27.4      51.2
# 9            16        Lorient            25     25.9      45.3
# 10           19  Clermont Foot            26     27.8      48.8
# 11           15       Toulouse            26     25.9      51.0
# 12           11    Montpellier            27     26.6      46.8
# 13            8         Nantes            27     27.5      46.0
# ...

# %%
# Concatenate all seasons into one dataframe
Ligue1_all_seasons_sum_df = pd.concat([Ligue1_2018_sum_clean_df, Ligue1_2019_sum_clean_df, Ligue1_2020_sum_clean_df,
                                Ligue1_2021_sum_clean_df, Ligue1_2022_sum_clean_df], axis=0)
Ligue1_all_seasons_sum_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 19
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   League Rank       100 non-null    int64
#  1   Squad             100 non-null    object
#  2   # of Players      100 non-null    int64
#  3   Avg Age           100 non-null    float64
#  4   Avg Poss          100 non-null    float64
#  5   MP                100 non-null    int64
#  6   W                 100 non-null    int64
#  7   D                 100 non-null    int64
#  8   L                 100 non-null    int64
#  9   GF                100 non-null    int64
#  10  GA                100 non-null    int64
#  11  GD                100 non-null    int64
#  12  Pts               100 non-null    int64
#  13  Pts/MP            100 non-null    float64
#  14  xG                100 non-null    float64
#  15  xGA               100 non-null    float64
# ...

# %%
Ligue1_all_seasons_sum_df['Annual Wages ($)'].value_counts()
# Out:
# 206,435,344    1
# 24,377,150     1
# 12,382,204     1
# 12,555,455     1
# 10,843,344     1
#               ..
# 13,944,506     1
# 27,188,881     1
# 9,076,207      1
# 13,438,006     1
# 7,640,191      1
# Name: Annual Wages ($), Length: 100, dtype: int64

# %%
# Get individual matches from each of te last 5 seasons
url = fixtures[0]
table_2018 = pd.read_html(url)
Ligue1_2018_matches_df = pd.DataFrame(table_2018[0])
url = fixtures[1]
table_2019 = pd.read_html(url)
Ligue1_2019_matches_df = pd.DataFrame(table_2019[0])
url = fixtures[2]
table_2020 = pd.read_html(url)
Ligue1_2020_matches_df = pd.DataFrame(table_2020[0])
url = fixtures[3]
table_2021 = pd.read_html(url)
Ligue1_2021_matches_df = pd.DataFrame(table_2021[0])
url = fixtures[4]
table_2022 = pd.read_html(url)
Ligue1_2022_matches_df = pd.DataFrame(table_2022[0])

# %%
# Drop empty rows
# Ligue1_all_matches_df.dropna(how='all')
Ligue1_2018_matches_df = Ligue1_2018_matches_df.dropna(how='all')
Ligue1_2019_matches_df = Ligue1_2019_matches_df.dropna(how='all')
Ligue1_2020_matches_df = Ligue1_2020_matches_df.dropna(how='all')
Ligue1_2021_matches_df = Ligue1_2021_matches_df.dropna(how='all')
Ligue1_2022_matches_df = Ligue1_2022_matches_df.dropna(how='all')
Ligue1_2022_matches_df.head()
# Out:
#             Round   Wk  Day        Date   Time      Home   xG Score  xG.1  \
# 0  Regular season  1.0  Fri  2021-08-06  21:00    Monaco  1.5   1–1   0.2
# 1  Regular season  1.0  Sat  2021-08-07  17:00      Lyon  1.4   1–1   0.8
# 2  Regular season  1.0  Sat  2021-08-07  21:00    Troyes  0.9   1–2   1.2
# 3  Regular season  1.0  Sun  2021-08-08  13:00    Rennes  0.7   1–1   2.1
# 4  Regular season  1.0  Sun  2021-08-08  15:00  Bordeaux  0.7   0–2   3.1
#
#             Away  Attendance                    Venue          Referee  \
# 0         Nantes      7500.0          Stade Louis II.   Antony Gautier
# 1          Brest     29018.0         Groupama Stadium    Mikael Lesage
# 2      Paris S-G     15248.0          Stade de l'Aube   Amaury Delerue
# 3           Lens     22567.0             Roazhon Park  Bastien Dechepy
# 4  Clermont Foot     18748.0  Stade Matmut-Atlantique    Florent Batta
#
#    Match Report Notes
# 0  Match Report   NaN
# 1  Match Report   NaN
# 2  Match Report   NaN
# ...

# %%
# Add seasons column
Ligue1_2018_matches_df['Season'] = '2017-2018'
Ligue1_2019_matches_df['Season'] = '2018-2019'
Ligue1_2020_matches_df['Season'] = '2019-2020'
Ligue1_2021_matches_df['Season'] = '2020-2021'
Ligue1_2022_matches_df['Season'] = '2021-2022'
#Ligue1_2022_matches_df.tail()

# %%
Ligue1_2022_matches_df.tail()
# Out:
#                                        Round    Wk  Day        Date   Time  \
# 419                           Regular season  38.0  Sat  2022-05-21  21:00
# 420                           Regular season  38.0  Sat  2022-05-21  21:00
# 421                           Regular season  38.0  Sat  2022-05-21  21:00
# 423  French 1/2 Relegation/Promotion Playoff   NaN  Thu  2022-05-26  19:00
# 424  French 1/2 Relegation/Promotion Playoff   NaN  Sun  2022-05-29  19:00
#
#               Home   xG        Score  xG.1           Away  Attendance  \
# 419          Reims  0.7          2–3   1.8           Nice     12589.0
# 420      Marseille  2.3          4–0   1.1     Strasbourg     63873.0
# 421           Lens  1.6          2–2   1.4         Monaco     37764.0
# 423        Auxerre  NaN          1–1   NaN  Saint-Étienne     17479.0
# 424  Saint-Étienne  NaN  (4) 1–1 (5)   NaN        Auxerre     24489.0
#
#                          Venue             Referee  Match Report  \
# ...

# %%
# Concatenate matches into one dataframe
Ligue1_all_matches_df = pd.concat([Ligue1_2018_matches_df,Ligue1_2019_matches_df, Ligue1_2020_matches_df,
                                Ligue1_2021_matches_df, Ligue1_2022_matches_df], axis=0)
#drop unwanted rows for French 1/2 Relegation
df_filtered = Ligue1_all_matches_df[Ligue1_all_matches_df['Round'] =='French 1/2 Relegation/Promotion Playoff'].index
Ligue1_all_matches_df.drop(df_filtered , inplace=True)
Ligue1_all_matches_df.tail()
# Out:
#               Round    Wk  Day        Date   Time       Home   xG Score  xG.1  \
# 417  Regular season  38.0  Sat  2022-05-21  21:00    Lorient  1.2   1–1   0.4
# 418  Regular season  38.0  Sat  2022-05-21  21:00  Paris S-G  5.4   5–0   0.7
# 419  Regular season  38.0  Sat  2022-05-21  21:00      Reims  0.7   2–3   1.8
# 420  Regular season  38.0  Sat  2022-05-21  21:00  Marseille  2.3   4–0   1.1
# 421  Regular season  38.0  Sat  2022-05-21  21:00       Lens  1.6   2–2   1.4
#
#            Away  Attendance                               Venue  \
# 417      Troyes     15131.0  Stade Yves Allainmat - Le Moustoir
# 418        Metz     45000.0                    Parc des Princes
# 419        Nice     12589.0            Stade Auguste-Delaune II
# 420  Strasbourg     63873.0                    Orange Vélodrome
# 421      Monaco     37764.0              Stade Bollaert-Delelis
#
#                 Referee  Match Report Notes     Season
# 417         Johan Hamel  Match Report   NaN  2021-2022
# ...

# %%
# Split 'Score' column into 'Home Score' & 'Away Score'
Ligue1_all_matches_df[['Home Score','Away Score']] = Ligue1_all_matches_df['Score'].str.split('–', expand=True)
Ligue1_all_matches_df.columns
# Out:
# Index(['Round', 'Wk', 'Day', 'Date', 'Time', 'Home', 'xG', 'Score', 'xG.1',
#        'Away', 'Attendance', 'Venue', 'Referee', 'Match Report', 'Notes',
#        'Season', 'Home Score', 'Away Score'],
#       dtype='object')

# %%
# Get list of columns
Ligue1_matches_reduced_df = Ligue1_all_matches_df[['Wk', 'Date', 'Time', 'Home', 'Away', 'Score', 'xG', 'xG.1', 
                                          'Attendance', 'Venue', 'Referee']]
Ligue1_all_matches_df.columns
# Out:
# Index(['Round', 'Wk', 'Day', 'Date', 'Time', 'Home', 'xG', 'Score', 'xG.1',
#        'Away', 'Attendance', 'Venue', 'Referee', 'Match Report', 'Notes',
#        'Season', 'Home Score', 'Away Score'],
#       dtype='object')

# %%
# Select desired columns
Ligue1_all_seasons_matches_df = Ligue1_all_matches_df[['Season', 'Wk', 'Date','Time', 'Home', 'Away', 'Home Score', 'Away Score', 'xG', 'xG.1',
                                       'Attendance', 'Venue', 'Referee']]
Ligue1_all_seasons_matches_df
# Out:
#         Season    Wk        Date   Time           Home        Away Home Score  \
# 0    2017-2018   1.0  2017-08-04  20:45         Monaco    Toulouse          3
# 1    2017-2018   1.0  2017-08-05  17:15      Paris S-G      Amiens          2
# 2    2017-2018   1.0  2017-08-05  20:00           Lyon  Strasbourg          4
# 3    2017-2018   1.0  2017-08-05  20:00  Saint-Étienne        Nice          1
# 4    2017-2018   1.0  2017-08-05  20:00           Metz    Guingamp          1
# ..         ...   ...         ...    ...            ...         ...        ...
# 417  2021-2022  38.0  2022-05-21  21:00        Lorient      Troyes          1
# 418  2021-2022  38.0  2022-05-21  21:00      Paris S-G        Metz          5
# 419  2021-2022  38.0  2022-05-21  21:00          Reims        Nice          2
# 420  2021-2022  38.0  2022-05-21  21:00      Marseille  Strasbourg          4
# 421  2021-2022  38.0  2022-05-21  21:00           Lens      Monaco          2
#
# ...

# %%
# Rename Columns
Ligue1_all_seasons_matches_df = Ligue1_all_seasons_matches_df.rename(columns={ 'xG': 'xG Home', 'xG.1': 'xG Away'}) 
Ligue1_all_seasons_matches_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1898 entries, 0 to 421
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Season      1898 non-null   object
#  1   Wk          1895 non-null   float64
#  2   Date        1898 non-null   object
#  3   Time        1825 non-null   object
#  4   Home        1898 non-null   object
#  5   Away        1898 non-null   object
#  6   Home Score  1797 non-null   object
#  7   Away Score  1797 non-null   object
#  8   xG Home     1794 non-null   float64
#  9   xG Away     1794 non-null   float64
#  10  Attendance  1406 non-null   float64
#  11  Venue       1898 non-null   object
#  12  Referee     1794 non-null   object
# dtypes: float64(4), object(9)
# memory usage: 207.6+ KB

# %%
#Create Calculated Columns
Ligue1_all_seasons_matches_df['xG Diff'] = Ligue1_all_seasons_matches_df['xG Home'] - Ligue1_all_seasons_matches_df['xG Away']
#Ligue1_all_seasons_matches_df["Home Score"].value_counts()
#Ligue1_all_seasons_matches_df["Away Score"].value_counts()

Ligue1_all_seasons_matches_df.tail(20)
# Out:
#         Season    Wk        Date   Time           Home           Away  \
# 401  2021-2022  37.0  2022-05-14  21:00           Nice          Lille
# 402  2021-2022  37.0  2022-05-14  21:00       Bordeaux        Lorient
# 403  2021-2022  37.0  2022-05-14  21:00    Montpellier      Paris S-G
# 404  2021-2022  37.0  2022-05-14  21:00         Rennes      Marseille
# 405  2021-2022  37.0  2022-05-14  21:00         Monaco          Brest
# 406  2021-2022  37.0  2022-05-14  21:00         Troyes           Lens
# 407  2021-2022  37.0  2022-05-14  21:00     Strasbourg  Clermont Foot
# 408  2021-2022  37.0  2022-05-14  21:00           Metz         Angers
# 409  2021-2022  37.0  2022-05-14  21:00           Lyon         Nantes
# 410  2021-2022  37.0  2022-05-14  21:00  Saint-Étienne          Reims
# 412  2021-2022  38.0  2022-05-21  21:00          Lille         Rennes
# 413  2021-2022  38.0  2022-05-21  21:00          Brest       Bordeaux
# ...

# %%
Ligue1_all_seasons_matches_df['Actual Diff'] = Ligue1_all_seasons_matches_df['Home Score'].astype(float) - Ligue1_all_seasons_matches_df['Away Score'].astype(float)

# %%
#Select desired columns
Ligue1_all_seasons_sum_df = Ligue1_all_seasons_sum_df[['Season', 'League Rank', 'Squad', '# of Players', 'Avg Age', 'Avg Poss', 'MP',
       'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Pts/MP', 'xG', 'xGA', 'xGD',
       'xGD/90', 'Attendance', 'Annual Wages ($)']]
Ligue1_all_seasons_sum_df = Ligue1_all_seasons_sum_df.reset_index(drop=True)
Ligue1_all_seasons_sum_df.sample(20)
# Out:
#        Season  League Rank          Squad  # of Players  Avg Age  Avg Poss  \
# 17  2017-2018            9       Toulouse            28     23.9      45.7
# 0   2017-2018            1      Paris S-G            35     26.1      66.3
# 77  2020-2021            9  Saint-Étienne            91     25.1      48.5
# 72  2020-2021           12    Montpellier            75     25.8      48.2
# 31  2018-2019           10         Nantes            97     25.9      50.1
# 69  2020-2021            6          Lille            77     26.1      50.8
# 76  2020-2021           20  Clermont Foot            89     26.9      50.0
# 24  2018-2019            3      Marseille            87     26.9      55.2
# 18  2017-2018           20         Troyes            30     26.7      42.6
# 41  2019-2020            1      Paris S-G            96     26.7      63.1
# 5   2017-2018            8       Bordeaux            37     25.1      50.6
# ...

# %%
# Remove comma from wages column to allow for conversion to float
#Ligue1_all_seasons_sum_df['Annual Wages ($)'] = Ligue1_all_seasons_sum_df['Annual Wages ($)'].map(lambda x: x.replace(',', ''))
#Ligue1_all_seasons_sum_df.sample(20)
# Convert wages column to float
#Ligue1_all_seasons_sum_df['Annual Wages ($)'] = Ligue1_all_seasons_sum_df['Annual Wages ($)'].astype(float)
# Out:
#        Season  League Rank        Squad  # of Players  Avg Age  Avg Poss  MP  \
# 29  2018-2019           14  Montpellier            30     26.4      47.0  38
# 90  2021-2022           15        Dijon            35     26.6      48.4  38
# 96  2021-2022            5        Lille            32     22.6      53.8  38
# 75  2020-2021           17         Caen            33     27.3      45.5  38
# 14  2017-2018           16   Strasbourg            31     27.2      49.1  38
# 20  2018-2019            1    Paris S-G            35     26.1      66.3  38
# 85  2021-2022            8     Bordeaux            37     25.1      50.6  38
# 27  2018-2019            6         Nice            39     25.0      58.1  38
# 84  2021-2022           11       Rennes            35     24.2      49.9  38
# 52  2019-2020           13       Amiens            34     27.5      43.3  38
# 54  2019-2020           16   Strasbourg            31     27.2      49.1  38
# ...

# %%
#Ligue1_all_seasons_matches_df
# Export cleaned data to csv files
Ligue1_all_seasons_sum_df['League']='Ligue1'
Ligue1_all_seasons_matches_df['League'] = 'Ligue1'
Ligue1_all_seasons_matches_df = Ligue1_all_seasons_matches_df.reset_index(drop=True)
Ligue1_all_seasons_matches_df = Ligue1_all_seasons_matches_df.dropna(subset=['Wk','Date'], how='all')
#Ligue1_all_seasons_matches_df
Ligue1_all_seasons_sum_df.to_csv('Ligue1_all_seasons_sum.csv', encoding= 'utf-8')
Ligue1_all_seasons_matches_df.to_csv('Ligue1_all_seasons_matches.csv', encoding= 'utf-8')
