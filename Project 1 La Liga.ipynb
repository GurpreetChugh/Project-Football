# %%
import pandas as pd
from highlight_text import ax_text, fig_text
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.pyplot as plt

# %%
laliga_22_23 = pd.read_html('https://fbref.com/en/comps/12/2017-2018/2017-2018-La-Liga-Stats')
la_liga_sum_2223 = laliga_22_23[1]
la_liga_sum_2223.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Home                            ...  \
#                   Rk              Squad   MP   W  D  L  GF  GA  GD Pts  ...
# 0                  1          Barcelona   19  16  3  0  53  11  42  51  ...
# 1                  2    Atlético Madrid   19  12  6  1  30   8  22  42  ...
# 2                  3        Real Madrid   19  12  4  3  54  20  34  40  ...
# 3                  4           Valencia   19  13  3  3  36  16  20  42  ...
# 4                  5         Villarreal   19  11  3  5  35  22  13  36  ...
#
#   Away
#      L  GF  GA  GD Pts Pts/MP    xG   xGA   xGD xGD/90
# 0    1  46  18  28  42   2.21  37.2  25.5  11.6   0.61
# 1    4  28  14  14  37   1.95  22.5  20.2   2.3   0.12
# 2    3  40  24  16  36   1.89  38.4  24.7  13.7   0.72
# 3    6  29  22   7  31   1.63  21.4  27.5  -6.1  -0.32
# 4    8  22  28  -6  25   1.32  21.6  30.1  -8.6  -0.45
#
# [5 rows x 28 columns]

# %%
laliga_21_22 = pd.read_html('https://fbref.com/en/comps/12/2021-2022/2021-2022-La-Liga-Stats')
la_liga_sum_2122 = laliga_21_22[1]
la_liga_sum_2122.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Home                            ...  \
#                   Rk              Squad   MP   W  D  L  GF  GA  GD Pts  ...
# 0                  1        Real Madrid   19  13  5  1  44  13  31  44  ...
# 1                  2          Barcelona   19  12  2  5  37  19  18  38  ...
# 2                  3    Atlético Madrid   19  12  5  2  33  16  17  41  ...
# 3                  4            Sevilla   19  12  6  1  36  17  19  42  ...
# 4                  5              Betis   19  10  2  7  34  22  12  32  ...
#
#   Away
#      L  GF  GA  GD Pts Pts/MP    xG   xGA   xGD xGD/90
# 0    3  36  18  18  42   2.21  33.4  23.3  10.1   0.53
# 1    2  31  19  12  35   1.84  29.5  19.0  10.5   0.55
# 2    7  32  27   5  30   1.58  25.4  20.5   4.9   0.26
# 3    3  17  13   4  28   1.47  17.8  20.3  -2.5  -0.13
# 4    4  28  18  10  33   1.74  23.8  22.8   1.0   0.05
#
# [5 rows x 28 columns]

# %%
laliga_20_21 = pd.read_html('https://fbref.com/en/comps/12/2020-2021/2020-2021-La-Liga-Stats')
la_liga_sum_2021 = laliga_20_21[1]
la_liga_sum_2021.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Home                            ...  \
#                   Rk              Squad   MP   W  D  L  GF  GA  GD Pts  ...
# 0                  1    Atlético Madrid   19  15  3  1  41  11  30  48  ...
# 1                  2        Real Madrid   19  13  3  3  33  13  20  42  ...
# 2                  3          Barcelona   19  11  5  3  44  20  24  38  ...
# 3                  4            Sevilla   19  14  1  4  27  11  16  43  ...
# 4                  5      Real Sociedad   19   9  6  4  34  21  13  33  ...
#
#   Away
#      L  GF  GA  GD Pts Pts/MP    xG   xGA   xGD xGD/90
# 0    3  26  14  12  38   2.00  23.2  19.3   3.9   0.21
# 1    1  34  15  19  42   2.21  32.9  21.5  11.4   0.60
# 2    4  41  18  23  41   2.16  33.5  19.6  13.9   0.73
# 3    5  26  22   4  34   1.79  26.9  18.6   8.3   0.44
# 4    6  25  17   8  29   1.53  25.1  20.1   4.9   0.26
#
# [5 rows x 28 columns]

# %%
laliga_19_20 = pd.read_html('https://fbref.com/en/comps/12/2019-2020/2019-2020-La-Liga-Stats')
la_liga_sum_1920 = laliga_19_20[1]
la_liga_sum_1920.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Home                            ...  \
#                   Rk              Squad   MP   W  D  L  GF  GA  GD Pts  ...
# 0                  1        Real Madrid   19  15  4  0  40  11  29  49  ...
# 1                  2          Barcelona   19  16  2  1  52  16  36  50  ...
# 2                  3    Atlético Madrid   19  12  6  1  28  11  17  42  ...
# 3                  4            Sevilla   19  10  7  2  26  14  12  37  ...
# 4                  5         Villarreal   19   9  5  5  37  25  12  32  ...
#
#   Away
#      L  GF  GA  GD Pts Pts/MP    xG   xGA   xGD xGD/90
# 0    3  30  14  16  38   2.00  30.1  18.4  11.7   0.62
# 1    5  34  22  12  32   1.68  28.4  21.0   7.4   0.39
# 2    3  23  16   7  28   1.47  26.6  19.2   7.3   0.39
# 3    4  28  20   8  33   1.74  24.4  19.6   4.8   0.25
# 4    9  26  24   2  28   1.47  30.5  22.8   7.6   0.40
#
# [5 rows x 28 columns]

# %%
laliga_18_19 = pd.read_html('https://fbref.com/en/comps/12/2018-2019/2018-2019-La-Liga-Stats')
la_liga_sum_1819 = laliga_18_19[1]
la_liga_sum_1819.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Home                             ...  \
#                   Rk              Squad   MP   W   D  L  GF  GA  GD Pts  ...
# 0                  1          Barcelona   19  15   3  1  51  17  34  48  ...
# 1                  2    Atlético Madrid   19  15   3  1  32  10  22  48  ...
# 2                  3        Real Madrid   19  13   1  5  32  15  17  40  ...
# 3                  4           Valencia   19   7  10  2  24  12  12  31  ...
# 4                  5             Getafe   19  11   3  5  28  13  15  36  ...
#
#   Away
#      L  GF  GA  GD Pts Pts/MP    xG   xGA  xGD xGD/90
# 0    2  39  19  20  39   2.05  30.4  22.1  8.3   0.44
# 1    5  23  19   4  28   1.47  21.3  24.1 -2.8  -0.15
# 2    7  31  31   0  28   1.47  30.9  27.7  3.2   0.17
# 3    5  27  23   4  30   1.58  29.5  28.2  1.3   0.07
# 4    4  20  22  -2  23   1.21  18.2  24.7 -6.5  -0.34
#
# [5 rows x 28 columns]

# %%
merged_df1 = pd.concat([la_liga_sum_2223,la_liga_sum_2122,la_liga_sum_2021,la_liga_sum_1920,la_liga_sum_1819], ignore_index=True)

# %%
summary_laliga_5years = merged_df1

# %%
summary_laliga_5years
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Home                             ...  \
#                    Rk              Squad   MP   W  D   L  GF  GA  GD Pts  ...
# 0                   1          Barcelona   19  16  3   0  53  11  42  51  ...
# 1                   2    Atlético Madrid   19  12  6   1  30   8  22  42  ...
# 2                   3        Real Madrid   19  12  4   3  54  20  34  40  ...
# 3                   4           Valencia   19  13  3   3  36  16  20  42  ...
# 4                   5         Villarreal   19  11  3   5  35  22  13  36  ...
# ..                ...                ...  ...  .. ..  ..  ..  ..  ..  ..  ...
# 95                 16         Valladolid   19   5  5   9  16  26 -10  20  ...
# 96                 17         Celta Vigo   19   8  5   6  31  25   6  29  ...
# 97                 18             Girona   19   3  6  10  17  28 -11  15  ...
# 98                 19             Huesca   19   5  6   8  24  30  -6  21  ...
# ...

# %%
laliga_22_23wages = pd.read_html('https://fbref.com/en/comps/12/wages/La-Liga-Wages')
la_liga_wages_2223df = pd.DataFrame(laliga_22_23wages[0])

# %%
la_liga_wages_2223df
# Out:
#     Rk            Squad  # Pl                           Weekly Wages  \
# 0    1        Barcelona    26  € 6,102,692 (£ 5,492,146, $5,872,258)
# 1    2      Real Madrid    23  € 5,348,654 (£ 4,813,546, $5,146,692)
# 2    3  Atlético Madrid    22  € 3,045,385 (£ 2,740,708, $2,930,393)
# 3    4          Sevilla    25  € 1,658,077 (£ 1,492,194, $1,595,469)
# 4    5       Villarreal    24  € 1,565,192 (£ 1,408,602, $1,506,092)
# 5    6    Athletic Club    26  € 1,215,962 (£ 1,094,310, $1,170,048)
# 6    7            Betis    26        € 828,750 (£ 745,837, $797,457)
# 7    8         Valencia    24        € 817,308 (£ 735,540, $786,447)
# 8    9    Real Sociedad    26        € 601,731 (£ 541,530, $579,010)
# 9   10       Celta Vigo    21        € 519,038 (£ 467,111, $499,440)
# 10  11           Getafe    24        € 408,654 (£ 367,770, $393,223)
# 11  12         Espanyol    22        € 303,654 (£ 273,275, $292,188)
# 12  13       Valladolid    24        € 246,250 (£ 221,614, $236,952)
# ...

# %%
laliga_21_22wages = pd.read_html('https://fbref.com/en/comps/12/2021-2022/wages/2021-2022-La-Liga-Wages')
la_liga_wages_2122df = pd.DataFrame(laliga_21_22wages[0])

# %%
print(la_liga_wages_2122df)
# Out:
#     Rk            Squad  # Pl                           Weekly Wages  \
# 0    1      Real Madrid    77  € 6,203,654 (£ 5,201,816, $6,322,216)
# 1    2        Barcelona    91  € 4,860,481 (£ 4,075,554, $4,953,373)
# 2    3  Atlético Madrid    70  € 3,217,885 (£ 2,698,223, $3,279,384)
# 3    4       Villarreal    78  € 2,039,615 (£ 1,710,235, $2,078,596)
# 4    5          Sevilla    82  € 1,908,462 (£ 1,600,261, $1,944,935)
# 5    6         Valencia    80  € 1,323,462 (£ 1,109,734, $1,348,755)
# 6    7    Athletic Club    78  € 1,232,692 (£ 1,033,623, $1,256,251)
# 7    8    Real Sociedad    80        € 970,192 (£ 813,514, $988,734)
# 8    9            Betis    83        € 922,500 (£ 773,524, $940,131)
# 9   10       Celta Vigo    64        € 738,077 (£ 618,884, $752,183)
# 10  11           Getafe    81        € 730,865 (£ 612,837, $744,833)
# 11  12         Espanyol    78        € 568,462 (£ 476,660, $579,326)
# 12  13          Granada    84        € 498,846 (£ 418,287, $508,380)
# ...

# %%
laliga_20_21wages = pd.read_html('https://fbref.com/en/comps/12/2020-2021/wages/2020-2021-La-Liga-Wages')
la_liga_wages_2021df = pd.DataFrame(laliga_20_21wages[0])

# %%
print(la_liga_wages_2021df)
# Out:
#     Rk            Squad  # Pl                           Weekly Wages  \
# 0    1        Barcelona    83  € 6,766,923 (£ 5,674,122, $6,896,250)
# 1    2      Real Madrid    70  € 6,044,038 (£ 5,067,977, $6,159,550)
# 2    3  Atlético Madrid    68  € 3,276,731 (£ 2,747,566, $3,339,355)
# 3    4       Villarreal    78  € 1,857,115 (£ 1,557,207, $1,892,608)
# 4    5          Sevilla    78  € 1,797,885 (£ 1,507,541, $1,832,245)
# 5    6         Valencia    78  € 1,449,808 (£ 1,215,676, $1,477,516)
# 6    7    Athletic Club    80  € 1,394,615 (£ 1,169,397, $1,421,269)
# 7    8    Real Sociedad    81      € 981,538 (£ 823,028, $1,000,297)
# 8    9       Celta Vigo    72        € 815,000 (£ 683,384, $830,576)
# 9   10            Betis    81        € 760,385 (£ 637,589, $774,917)
# 10  11          Granada    80        € 520,385 (£ 436,347, $530,330)
# 11  12           Getafe    71        € 495,962 (£ 415,868, $505,440)
# 12  13          Osasuna    77        € 483,462 (£ 405,387, $492,701)
# ...

# %%
laliga_19_20wages = pd.read_html('https://fbref.com/en/comps/12/2019-2020/wages/2019-2020-La-Liga-Wages')
la_liga_wages_1920df = pd.DataFrame(laliga_19_20wages[0])

# %%
print(la_liga_wages_1920df)
# Out:
#     Rk            Squad  # Pl                           Weekly Wages  \
# 0    1      Real Madrid    79  € 6,850,000 (£ 5,743,782, $6,980,915)
# 1    2        Barcelona    69  € 6,631,731 (£ 5,560,762, $6,758,474)
# 2    3  Atlético Madrid    68  € 3,182,692 (£ 2,668,714, $3,243,519)
# 3    4         Valencia    74  € 1,448,846 (£ 1,214,870, $1,476,536)
# 4    5          Sevilla    74  € 1,259,808 (£ 1,056,359, $1,283,885)
# 5    6       Villarreal    78    € 1,142,115 (£ 957,673, $1,163,943)
# 6    7    Athletic Club    76        € 929,423 (£ 779,329, $947,186)
# 7    8    Real Sociedad    73        € 751,731 (£ 630,333, $766,098)
# 8    9       Celta Vigo    75        € 721,731 (£ 605,177, $735,524)
# 9   10            Betis    73        € 696,538 (£ 584,053, $709,850)
# 10  11          Leganés    77        € 679,231 (£ 569,541, $692,212)
# 11  12         Espanyol    81        € 644,615 (£ 540,515, $656,935)
# 12  13           Getafe    79        € 508,846 (£ 426,672, $518,571)
# ...

# %%
laliga_18_19wages = pd.read_html('https://fbref.com/en/comps/12/2018-2019/wages/2018-2019-La-Liga-Wages')
la_liga_wages_1819df = pd.DataFrame(laliga_18_19wages[0])

# %%
print(la_liga_wages_1819df)
# Out:
#     Rk            Squad  # Pl                           Weekly Wages  \
# 0    1        Barcelona    92  € 5,152,596 (£ 4,320,495, $5,251,071)
# 1    2      Real Madrid    91  € 4,466,808 (£ 3,745,456, $4,552,176)
# 2    3  Atlético Madrid    88  € 3,896,462 (£ 3,267,216, $3,970,930)
# 3    4          Sevilla    86  € 1,487,212 (£ 1,247,039, $1,515,635)
# 4    5         Valencia    80  € 1,454,231 (£ 1,219,385, $1,482,024)
# 5    6       Celta Vigo   124  € 1,340,096 (£ 1,123,682, $1,365,708)
# 6    7    Athletic Club    86    € 1,089,365 (£ 913,442, $1,110,185)
# 7    8       Villarreal    87        € 945,865 (£ 793,116, $963,942)
# 8    9    Real Sociedad    81        € 732,712 (£ 614,385, $746,715)
# 9   10            Betis    81        € 711,269 (£ 596,405, $724,863)
# 10  11          Levante    86        € 696,885 (£ 584,344, $710,203)
# 11  12         Espanyol    81        € 612,442 (£ 513,538, $624,147)
# 12  13           Alavés    76        € 434,904 (£ 364,671, $443,216)
# ...

# %%
merged_df2 = pd.concat([la_liga_wages_2223df,la_liga_wages_2122df,la_liga_wages_2021df,la_liga_wages_1920df,la_liga_wages_1819df],ignore_index=True)
wages_laliga_5years = merged_df2

# %%
wages_laliga_5years
# Out:
#     Rk            Squad  # Pl                           Weekly Wages  \
# 0    1        Barcelona    26  € 6,102,692 (£ 5,492,146, $5,872,258)
# 1    2      Real Madrid    23  € 5,348,654 (£ 4,813,546, $5,146,692)
# 2    3  Atlético Madrid    22  € 3,045,385 (£ 2,740,708, $2,930,393)
# 3    4          Sevilla    25  € 1,658,077 (£ 1,492,194, $1,595,469)
# 4    5       Villarreal    24  € 1,565,192 (£ 1,408,602, $1,506,092)
# ..  ..              ...   ...                                    ...
# 94  15            Eibar    79        € 386,212 (£ 323,842, $393,593)
# 95  16           Getafe    78        € 368,750 (£ 309,200, $375,797)
# 96  17           Girona    79        € 357,385 (£ 299,670, $364,215)
# 97  18       Valladolid    86        € 316,346 (£ 265,259, $322,392)
# 98  19           Huesca    88        € 296,865 (£ 248,924, $302,539)
#
#                                    Annual Wages % Estimated
# 0   € 317,340,000 (£ 285,591,609, $305,357,425)         20%
# ...

# %%
laliga_2223sandf = pd.read_html('https://fbref.com/en/comps/12/schedule/La-Liga-Scores-and-Fixtures')
la_liga_2223sandf = pd.DataFrame(laliga_2223sandf[0])

# %%
print(la_liga_2223sandf)
# Out:
#        Wk  Day        Date   Time         Home   xG Score  xG.1  \
# 0     1.0  Fri  2022-08-12  21:00      Osasuna  1.5   2–1   0.9
# 1     1.0  Sat  2022-08-13  17:00   Celta Vigo  0.4   2–2   1.1
# 2     1.0  Sat  2022-08-13  19:00   Valladolid  1.0   0–3   1.5
# 3     1.0  Sat  2022-08-13  21:00    Barcelona  1.9   0–0   0.5
# 4     1.0  Sun  2022-08-14  17:30        Cádiz  0.2   0–1   1.5
# ..    ...  ...         ...    ...          ...  ...   ...   ...
# 413  38.0  Sun  2023-06-04    NaN   Celta Vigo  NaN   NaN   NaN
# 414  38.0  Sun  2023-06-04    NaN     Espanyol  NaN   NaN   NaN
# 415  38.0  Sun  2023-06-04    NaN  Real Madrid  NaN   NaN   NaN
# 416  38.0  Sun  2023-06-04    NaN      Osasuna  NaN   NaN   NaN
# 417  38.0  Sun  2023-06-04    NaN     Mallorca  NaN   NaN   NaN
#
#                Away  Attendance                            Venue  \
# 0           Sevilla     18536.0                 Estadio El Sadar
# ...

# %%
laliga_2122sandf = pd.read_html('https://fbref.com/en/comps/12/2021-2022/schedule/2021-2022-La-Liga-Scores-and-Fixtures')
la_liga_2122sandf = pd.DataFrame(laliga_2122sandf[0])

# %%
print(la_liga_2122sandf)
# Out:
#        Wk  Day        Date   Time           Home   xG Score  xG.1  \
# 0     1.0  Fri  2021-08-13  21:00       Valencia  1.5   1–0   1.4
# 1     1.0  Sat  2021-08-14  19:30       Mallorca  0.5   1–1   0.6
# 2     1.0  Sat  2021-08-14  19:30          Cádiz  0.6   1–1   0.9
# 3     1.0  Sat  2021-08-14  22:00         Alavés  1.7   1–4   1.7
# 4     1.0  Sat  2021-08-14  22:00        Osasuna  0.9   0–0   0.5
# ..    ...  ...         ...    ...            ...  ...   ...   ...
# 419  38.0  Sun  2022-05-22  20:00        Granada  1.7   0–0   0.3
# 420  38.0  Sun  2022-05-22  20:00         Alavés  0.4   0–1   1.8
# 421  38.0  Sun  2022-05-22  22:00      Barcelona  0.6   0–2   0.8
# 422  38.0  Sun  2022-05-22  22:00        Sevilla  1.2   1–0   0.7
# 423  38.0  Sun  2022-05-22  22:00  Real Sociedad  2.5   1–2   0.7
#
#                 Away  Attendance                          Venue  \
# 0             Getafe      9868.0            Estadio de Mestalla
# ...

# %%
laliga_2021sandf = pd.read_html('https://fbref.com/en/comps/12/2020-2021/schedule/2020-2021-La-Liga-Scores-and-Fixtures')
la_liga_2021sandf = pd.DataFrame(laliga_2021sandf[0])

# %%
print(la_liga_2021sandf)
# Out:
#        Wk  Day        Date   Time        Home   xG Score  xG.1  \
# 0     1.0  Sat  2020-09-12  16:00       Eibar  0.4   0–0   0.6
# 1     1.0  Sat  2020-09-12  18:30     Granada  0.4   2–0   0.5
# 2     1.0  Sat  2020-09-12  21:00       Cádiz  0.7   0–2   0.8
# 3     1.0  Sun  2020-09-13  14:00      Alavés  1.2   0–1   0.4
# 4     1.0  Sun  2020-09-13  16:00  Valladolid  0.8   1–1   0.3
# ..    ...  ...         ...    ...         ...  ...   ...   ...
# 422  38.0  Sat  2021-05-22  18:00  Celta Vigo  1.3   2–3   2.3
# 423  38.0  Sat  2021-05-22  18:00  Valladolid  1.1   1–2   1.4
# 424  38.0  Sat  2021-05-22  18:00       Eibar  1.7   0–1   0.3
# 425  38.0  Sun  2021-05-23  18:30     Granada  0.4   0–0   0.6
# 426  38.0  Sun  2021-05-23  21:00     Sevilla  0.4   1–0   1.1
#
#                 Away  Attendance                            Venue  \
# 0         Celta Vigo         NaN      Estadio Municipal de Ipurúa
# 1      Athletic Club         NaN       Estadio Nuevo Los Cármenes
# ...

# %%
laliga_1920sandf = pd.read_html('https://fbref.com/en/comps/12/2019-2020/schedule/2019-2020-La-Liga-Scores-and-Fixtures')
la_liga_1920sandf = pd.DataFrame(laliga_1920sandf[0])

# %%
print(la_liga_1920sandf)
# Out:
#        Wk  Day        Date   Time           Home   xG Score  xG.1  \
# 0     1.0  Fri  2019-08-16  21:00  Athletic Club  0.5   1–0   0.9
# 1     1.0  Sat  2019-08-17  17:00     Celta Vigo  1.6   1–3   2.1
# 2     1.0  Sat  2019-08-17  19:00       Valencia  2.3   1–1   1.8
# 3     1.0  Sat  2019-08-17  20:00       Mallorca  1.6   2–1   0.7
# 4     1.0  Sat  2019-08-17  21:00        Leganés  1.4   0–1   0.2
# ..    ...  ...         ...    ...            ...  ...   ...   ...
# 414  38.0  Sun  2020-07-19  21:00        Levante  2.4   1–0   1.4
# 415  38.0  Sun  2020-07-19  21:00        Granada  1.6   4–0   0.7
# 416  38.0  Sun  2020-07-19  21:00        Leganés  1.4   2–2   0.8
# 417  38.0  Sun  2020-07-19  21:00        Osasuna  0.9   2–2   0.8
# 418  38.0  Sun  2020-07-19  21:00       Espanyol  0.4   0–0   0.6
#
#               Away  Attendance                          Venue  \
# 0        Barcelona     47693.0                      San Mamés
# ...

# %%
laliga_1819sandf = pd.read_html('https://fbref.com/en/comps/12/2018-2019/schedule/2018-2019-La-Liga-Scores-and-Fixtures')
la_liga_1819sandf = pd.DataFrame(laliga_1819sandf[0])

# %%
print(la_liga_1819sandf)
# Out:
#        Wk  Day        Date   Time         Home   xG Score  xG.1  \
# 0     1.0  Fri  2018-08-17  20:15       Girona  0.7   0–0   0.0
# 1     1.0  Fri  2018-08-17  22:15        Betis  0.9   0–3   2.5
# 2     1.0  Sat  2018-08-18  18:15   Celta Vigo  0.6   1–1   0.6
# 3     1.0  Sat  2018-08-18  20:15   Villarreal  1.6   1–2   0.7
# 4     1.0  Sat  2018-08-18  22:15    Barcelona  3.2   3–0   0.3
# ..    ...  ...         ...    ...          ...  ...   ...   ...
# 413  38.0  Sat  2019-05-18  20:45   Celta Vigo  2.1   2–2   1.4
# 414  38.0  Sat  2019-05-18  20:45       Huesca  0.9   2–1   0.9
# 415  38.0  Sat  2019-05-18  20:45       Alavés  1.3   2–1   1.0
# 416  38.0  Sun  2019-05-19  12:00  Real Madrid  0.9   0–2   1.3
# 417  38.0  Sun  2019-05-19  16:15        Eibar  1.5   2–2   1.1
#
#                Away  Attendance                          Venue  \
# 0        Valladolid     10368.0  Estadi Municipal de Montilivi
# 1           Levante     46225.0      Estadio Benito Villamarín
# ...

# %%
merged_df3 = pd.concat([la_liga_2223sandf,la_liga_2122sandf,la_liga_2021sandf,la_liga_1920sandf,la_liga_1819sandf],ignore_index=True)
scoresandfictures_laliga_5years = merged_df3

# %%
print(scoresandfictures_laliga_5years)
# Out:
#         Wk  Day        Date   Time         Home   xG Score  xG.1  \
# 0      1.0  Fri  2022-08-12  21:00      Osasuna  1.5   2–1   0.9
# 1      1.0  Sat  2022-08-13  17:00   Celta Vigo  0.4   2–2   1.1
# 2      1.0  Sat  2022-08-13  19:00   Valladolid  1.0   0–3   1.5
# 3      1.0  Sat  2022-08-13  21:00    Barcelona  1.9   0–0   0.5
# 4      1.0  Sun  2022-08-14  17:30        Cádiz  0.2   0–1   1.5
# ...    ...  ...         ...    ...          ...  ...   ...   ...
# 2101  38.0  Sat  2019-05-18  20:45   Celta Vigo  2.1   2–2   1.4
# 2102  38.0  Sat  2019-05-18  20:45       Huesca  0.9   2–1   0.9
# 2103  38.0  Sat  2019-05-18  20:45       Alavés  1.3   2–1   1.0
# 2104  38.0  Sun  2019-05-19  12:00  Real Madrid  0.9   0–2   1.3
# 2105  38.0  Sun  2019-05-19  16:15        Eibar  1.5   2–2   1.1
#
#                 Away  Attendance                            Venue  \
# 0            Sevilla     18536.0                 Estadio El Sadar
# ...
