# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import scipy.stats as stats
import seaborn as sns

# %% [markdown]
# # Bundesliga Stats

# %%
#Stats for 2017-2018
table_1 = pd.read_html('https://fbref.com/en/comps/20/2017-2018/2017-2018-Bundesliga-Stats')
Bundes_Table_1718 = pd.DataFrame(table_1[0])
Bundes_Table_1718
# Out:
#     Rk           Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0    1   Bayern Munich  34  27   3   4  92  28  64   84    2.47  75.8  31.7
# 1    2      Schalke 04  34  18   9   7  53  37  16   63    1.85  46.7  40.2
# 2    3      Hoffenheim  34  15  10   9  66  48  18   55    1.62  50.5  47.2
# 3    4        Dortmund  34  15  10   9  64  47  17   55    1.62  66.0  42.2
# 4    5      Leverkusen  34  15  10   9  58  44  14   55    1.62  57.5  38.9
# 5    6      RB Leipzig  34  15   8  11  57  53   4   53    1.56  51.9  46.7
# 6    7       Stuttgart  34  15   6  13  36  36   0   51    1.50  40.3  43.5
# 7    8  Eint Frankfurt  34  14   7  13  45  45   0   49    1.44  42.2  41.7
# 8    9      M'Gladbach  34  13   8  13  47  52  -5   47    1.38  51.1  52.0
# 9   10      Hertha BSC  34  10  13  11  43  46  -3   43    1.26  39.2  44.3
# 10  11   Werder Bremen  34  10  12  12  37  40  -3   42    1.24  38.9  45.1
# ...

# %%
#Stats for 2018-2019
table_2 = pd.read_html('https://fbref.com/en/comps/20/2018-2019/2018-2019-Bundesliga-Stats')
Bundes_Table_1819 = pd.DataFrame(table_2[0])
Bundes_Table_1819
# Out:
#     Rk           Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0    1   Bayern Munich  34  24   6   4  88  32  56   78    2.29  85.6  27.2
# 1    2        Dortmund  34  23   7   4  81  44  37   76    2.24  61.5  39.9
# 2    3      RB Leipzig  34  19   9   6  63  29  34   66    1.94  65.7  40.5
# 3    4      Leverkusen  34  18   4  12  69  52  17   58    1.71  58.3  44.0
# 4    5      M'Gladbach  34  16   7  11  55  42  13   55    1.62  52.2  52.3
# 5    6       Wolfsburg  34  16   7  11  62  50  12   55    1.62  47.6  48.3
# 6    7  Eint Frankfurt  34  15   9  10  60  48  12   54    1.59  57.2  50.7
# 7    8   Werder Bremen  34  14  11   9  58  49   9   53    1.56  49.8  56.1
# 8    9      Hoffenheim  34  13  12   9  70  52  18   51    1.50  75.9  52.5
# 9   10      Düsseldorf  34  13   5  16  49  65 -16   44    1.29  47.1  62.4
# 10  11      Hertha BSC  34  11  10  13  49  57  -8   43    1.26  51.0  61.4
# ...

# %%
#Stats for 2019-2020
table_3 = pd.read_html('https://fbref.com/en/comps/20/2019-2020/2019-2020-Bundesliga-Stats')
Bundes_Table_1920 = pd.DataFrame(table_3[0])
Bundes_Table_1920
# Out:
#     Rk           Squad  MP   W   D   L   GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0    1   Bayern Munich  34  26   4   4  100  32  68   82    2.41  89.5  37.9
# 1    2        Dortmund  34  21   6   7   84  41  43   69    2.03  61.0  40.9
# 2    3      RB Leipzig  34  18  12   4   81  37  44   66    1.94  71.3  38.8
# 3    4      M'Gladbach  34  20   5   9   66  40  26   65    1.91  72.0  45.9
# 4    5      Leverkusen  34  19   6   9   61  44  17   63    1.85  59.1  51.2
# 5    6      Hoffenheim  34  15   7  12   53  53   0   52    1.53  56.1  59.6
# 6    7       Wolfsburg  34  13  10  11   48  46   2   49    1.44  52.8  42.9
# 7    8        Freiburg  34  13   9  12   48  47   1   48    1.41  46.7  64.6
# 8    9  Eint Frankfurt  34  13   6  15   59  60  -1   45    1.32  59.5  49.9
# 9   10      Hertha BSC  34  11   8  15   48  59 -11   41    1.21  43.1  54.5
# 10  11    Union Berlin  34  12   5  17   41  58 -17   41    1.21  41.4  54.3
# ...

# %%
#Stats for 2020-21
table_4 =  pd.read_html('https://fbref.com/en/comps/20/2020-2021/2020-2021-Bundesliga-Stats')
Bundes_Table_2021 = pd.DataFrame(table_4[0])
Bundes_Table_2021
# Out:
#     Rk           Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0    1   Bayern Munich  34  24   6   4  99  44  55   78    2.29  75.9  40.2
# 1    2      RB Leipzig  34  19   8   7  60  32  28   65    1.91  64.4  29.4
# 2    3        Dortmund  34  20   4  10  75  46  29   64    1.88  66.2  41.6
# 3    4       Wolfsburg  34  17  10   7  61  37  24   61    1.79  49.0  42.1
# 4    5  Eint Frankfurt  34  16  12   6  69  53  16   60    1.76  58.5  46.9
# 5    6      Leverkusen  34  14  10  10  53  39  14   52    1.53  46.3  39.2
# 6    7    Union Berlin  34  12  14   8  50  43   7   50    1.47  46.9  42.8
# 7    8      M'Gladbach  34  13  10  11  64  56   8   49    1.44  54.9  45.7
# 8    9       Stuttgart  34  12   9  13  56  55   1   45    1.32  51.4  52.1
# 9   10        Freiburg  34  12   9  13  52  52   0   45    1.32  45.5  52.4
# 10  11      Hoffenheim  34  11  10  13  52  54  -2   43    1.26  51.9  53.1
# ...

# %%
#Stats for 2021-22
table_5 =  pd.read_html('https://fbref.com/en/comps/20/2021-2022/2021-2022-Bundesliga-Stats')
Bundes_Table_2122 = pd.DataFrame(table_5[0])
Bundes_Table_2122
# Out:
#     Rk           Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0    1   Bayern Munich  34  24   5   5  97  37  60   77    2.26  89.0  36.3
# 1    2        Dortmund  34  22   3   9  85  52  33   69    2.03  64.0  46.3
# 2    3      Leverkusen  34  19   7   8  80  47  33   64    1.88  62.6  44.0
# 3    4      RB Leipzig  34  17   7  10  72  37  35   58    1.71  64.5  40.1
# 4    5    Union Berlin  34  16   9   9  50  44   6   57    1.68  47.0  38.5
# 5    6        Freiburg  34  15  10   9  58  46  12   55    1.62  50.4  44.0
# 6    7            Köln  34  14  10  10  52  49   3   52    1.53  50.1  50.6
# 7    8        Mainz 05  34  13   7  14  50  45   5   46    1.35  50.4  43.9
# 8    9      Hoffenheim  34  13   7  14  58  60  -2   46    1.35  58.3  54.6
# 9   10      M'Gladbach  34  12   9  13  54  61  -7   45    1.32  56.2  55.0
# 10  11  Eint Frankfurt  34  10  12  12  45  49  -4   42    1.24  41.6  47.0
# ...

# %%
combined_bundesliga_df = pd.concat([Bundes_Table_2018,
                                    Bundes_Table_2019,
                                    Bundes_Table_2020,
                                    Bundes_Table_2021,
                                    Bundes_Table_2022])
combined_bundesliga_df.sample(10)
# Out:
#     Rk          Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 1    2       Dortmund  34  23   7   4  81  44  37   76    2.24  61.5  39.9
# 12  13       Mainz 05  34  11   4  19  44  65 -21   37    1.09  48.2  59.6
# 2    3     Hoffenheim  34  15  10   9  66  48  18   55    1.62  50.5  47.2
# 9   10     Hertha BSC  34  10  13  11  43  46  -3   43    1.26  39.2  44.3
# 4    5     Leverkusen  34  19   6   9  61  44  17   63    1.85  59.1  51.2
# 0    1  Bayern Munich  34  27   3   4  92  28  64   84    2.47  75.8  31.7
# 8    9     M'Gladbach  34  13   8  13  47  52  -5   47    1.38  51.1  52.0
# 0    1  Bayern Munich  34  24   5   5  97  37  60   77    2.26  89.0  36.3
# 9   10     Düsseldorf  34  13   5  16  49  65 -16   44    1.29  47.1  62.4
# 9   10     Hertha BSC  34  11   8  15  48  59 -11   41    1.21  43.1  54.5
#
#      xGD  xGD/90  Attendance                     Top Team Scorer  \
# 1   21.5    0.63       80841                   Paco Alcácer - 18
# ...

# %% [markdown]
# # Bundesliga Team Age

# %%
#2017 - 2018 age
table_1 = pd.read_html('https://fbref.com/en/comps/20/2017-2018/2017-2018-Bundesliga-Stats')
Bundes_TeamAge_1718 = pd.DataFrame(table_1[2])
Bundes_TeamAge
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Squad               # Pl                Age
# 0             Arminia                 26               25.8
# 1            Augsburg                 26               26.6
# 2       Bayern Munich                 30               26.8
# 3              Bochum                 28               28.0
# 4            Dortmund                 33               25.9
# 5      Eint Frankfurt                 27               26.2
# 6            Freiburg                 26               26.5
# 7      Greuther Fürth                 29               25.9
# 8          Hertha BSC                 36               26.7
# 9          Hoffenheim                 32               26.1
# 10               Köln                 26               27.0
# 11         Leverkusen                 29               24.4
# 12         M'Gladbach                 26               26.0
# 13           Mainz 05                 28               26.2
# ...

# %%
#2018 - 2019 age
table_2 = pd.read_html('https://fbref.com/en/comps/20/2018-2019/2018-2019-Bundesliga-Stats')
Bundes_TeamAge_1819 = pd.DataFrame(table_2[2])
Bundes_TeamAge
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Squad               # Pl                Age
# 0             Arminia                 26               25.8
# 1            Augsburg                 26               26.6
# 2       Bayern Munich                 30               26.8
# 3              Bochum                 28               28.0
# 4            Dortmund                 33               25.9
# 5      Eint Frankfurt                 27               26.2
# 6            Freiburg                 26               26.5
# 7      Greuther Fürth                 29               25.9
# 8          Hertha BSC                 36               26.7
# 9          Hoffenheim                 32               26.1
# 10               Köln                 26               27.0
# 11         Leverkusen                 29               24.4
# 12         M'Gladbach                 26               26.0
# 13           Mainz 05                 28               26.2
# ...

# %%
#2019 - 2020 age
table_3 = pd.read_html('https://fbref.com/en/comps/20/2019-2020/2019-2020-Bundesliga-Stats')
Bundes_TeamAge_1920 = pd.DataFrame(table_3[2])
Bundes_TeamAge
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Squad               # Pl                Age
# 0             Arminia                 26               25.8
# 1            Augsburg                 26               26.6
# 2       Bayern Munich                 30               26.8
# 3              Bochum                 28               28.0
# 4            Dortmund                 33               25.9
# 5      Eint Frankfurt                 27               26.2
# 6            Freiburg                 26               26.5
# 7      Greuther Fürth                 29               25.9
# 8          Hertha BSC                 36               26.7
# 9          Hoffenheim                 32               26.1
# 10               Köln                 26               27.0
# 11         Leverkusen                 29               24.4
# 12         M'Gladbach                 26               26.0
# 13           Mainz 05                 28               26.2
# ...

# %%
#2020 - 2021 age
table_4 = pd.read_html('https://fbref.com/en/comps/20/2020-2021/2020-2021-Bundesliga-Stats')
Bundes_TeamAge_2021 = pd.DataFrame(table_4[2])
Bundes_TeamAge
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Squad               # Pl                Age
# 0             Arminia                 26               25.8
# 1            Augsburg                 26               26.6
# 2       Bayern Munich                 30               26.8
# 3              Bochum                 28               28.0
# 4            Dortmund                 33               25.9
# 5      Eint Frankfurt                 27               26.2
# 6            Freiburg                 26               26.5
# 7      Greuther Fürth                 29               25.9
# 8          Hertha BSC                 36               26.7
# 9          Hoffenheim                 32               26.1
# 10               Köln                 26               27.0
# 11         Leverkusen                 29               24.4
# 12         M'Gladbach                 26               26.0
# 13           Mainz 05                 28               26.2
# ...

# %%
#2021 - 2022 age
table_5 = pd.read_html('https://fbref.com/en/comps/20/2021-2022/2021-2022-Bundesliga-Stats')
Bundes_TeamAge_2122 = pd.DataFrame(table_5[2])
Bundes_TeamAge
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Squad               # Pl                Age
# 0             Arminia                 26               25.8
# 1            Augsburg                 26               26.6
# 2       Bayern Munich                 30               26.8
# 3              Bochum                 28               28.0
# 4            Dortmund                 33               25.9
# 5      Eint Frankfurt                 27               26.2
# 6            Freiburg                 26               26.5
# 7      Greuther Fürth                 29               25.9
# 8          Hertha BSC                 36               26.7
# 9          Hoffenheim                 32               26.1
# 10               Köln                 26               27.0
# 11         Leverkusen                 29               24.4
# 12         M'Gladbach                 26               26.0
# 13           Mainz 05                 28               26.2
# ...

# %%
combined_bunesdliga_age = pd.concat([Bundes_TeamAge_1718,
                                     Bundes_TeamAge_1819,
                                   Bundes_TeamAge_1920,
                                  Bundes_TeamAge_2021,
                                  Bundes_TeamAge_2122   ])
combined_bunesdliga_age.sample(10)
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Squad               # Pl                Age
# 3          Düsseldorf                 28               27.1
# 16      Werder Bremen                 25               26.3
# 6         Hannover 96                 32               26.3
# 3              Bochum                 28               28.0
# 12         RB Leipzig                 25               25.0
# 9          Leverkusen                 21               25.3
# 8          Hertha BSC                 36               26.7
# 14          Stuttgart                 29               24.1
# 13         RB Leipzig                 29               24.2
# 11         Leverkusen                 29               24.4
#
#    Unnamed: 3_level_0 Playing Time                    Performance      ...  \
#                  Poss           MP Starts   Min   90s         Gls Ast  ...
# 3                45.6           34    374  3060  34.0          36  26  ...
# ...

# %% [markdown]
# # Bundesliga Match Data

# %%
table_1 = pd.read_html('https://fbref.com/en/comps/20/2017-2018/schedule/2017-2018-Bundesliga-Scores-and-Fixtures')
Bundes_Matches1718 = pd.DataFrame(table_1[0])
Bundes_Matches1718["Season"] = "2017-18"

# %%
table_2 = pd.read_html('https://fbref.com/en/comps/20/2018-2019/schedule/2018-2019-Bundesliga-Scores-and-Fixtures')
Bundes_Matches1819 = pd.DataFrame(table_2[0])
Bundes_Matches1819["Season"] = "2018-19"

# %%
table_3 = pd.read_html('https://fbref.com/en/comps/20/2019-2020/schedule/2019-2020-Bundesliga-Scores-and-Fixtures')
Bundes_Matches1920 = pd.DataFrame(table_3[0])
Bundes_Matches1920["Season"] = "2019-20"

# %%
table_4 = pd.read_html('https://fbref.com/en/comps/20/2020-2021/schedule/2020-2021-Bundesliga-Scores-and-Fixtures')
Bundes_Matches2021 = pd.DataFrame(table_4[0])
Bundes_Matches2021["Season"] = "2020-21"

# %%
table_5 = pd.read_html('https://fbref.com/en/comps/20/2021-2022/schedule/2021-2022-Bundesliga-Scores-and-Fixtures')
Bundes_Matches2022 = pd.DataFrame(table_5[0])
Bundes_Matches2122["Season"] = "2021-22"

# %%
combined_bundesliga_matches = pd.concat([Bundes_Matches1718,
                                        Bundes_Matches1819,
                                       Bundes_Matches1920,
                                       Bundes_Matches2021,
                                       Bundes_Matches2022 ])
combined_bundesliga_matches.sample(10)
# Out:
#               Round    Wk  Day        Date   Time          Home   xG Score  \
# 14   Regular season   2.0  Sat  2017-08-26  15:30    Leverkusen  2.2   2–2
# 196  Regular season  20.0  Sat  2021-02-06  18:30    M'Gladbach  0.5   1–2
# 77   Regular season   8.0  Sun  2019-10-20  15:30          Köln  2.4   3–0
# 249  Regular season  26.0  Sat  2022-03-12  15:30  Union Berlin  1.5   1–1
# 145  Regular season  15.0  Sat  2021-01-09  15:30    Schalke 04  2.0   4–0
# 30   Regular season   4.0  Sat  2020-10-17  15:30      Augsburg  1.0   0–2
# 99              NaN   NaN  NaN         NaN    NaN           NaN  NaN   NaN
# 111  Regular season  12.0  Sat  2018-11-24  15:30      Mainz 05  1.2   1–2
# 75   Regular season   8.0  Sat  2018-10-20  15:30      Nürnberg  1.1   1–3
# 108  Regular season  11.0  Sun  2019-11-10  18:00      Freiburg  0.9   1–0
#
#      xG.1            Away  Attendance                           Venue  \
# 14    0.9      Hoffenheim     27106.0                        BayArena
# ...

# %% [markdown]
# # Bundesliga Team Wages

# %%
table_1 = pd.read_html('https://fbref.com/en/comps/20/2017-2018/wages/2017-2018-Bundesliga-Wages')
Bundes_Wages1718 = pd.DataFrame(table_1[0])
Bundes_Wages1718
# Out:
#     Rk           Squad  # Pl                           Weekly Wages  \
# 0    1   Bayern Munich    38  € 3,491,942 (£ 2,928,023, $3,558,679)
# 1    2        Dortmund    33  € 1,593,981 (£ 1,336,566, $1,624,444)
# 2    3       Wolfsburg    33    € 1,119,346 (£ 938,581, $1,140,739)
# 3    4      Leverkusen    27    € 1,093,019 (£ 916,506, $1,113,909)
# 4    5      M'Gladbach    35        € 859,173 (£ 720,424, $875,593)
# 5    6      RB Leipzig    28        € 815,481 (£ 683,787, $831,066)
# 6    7      Schalke 04    29        € 801,500 (£ 672,064, $816,818)
# 7    8      Hoffenheim    36        € 746,250 (£ 625,737, $760,512)
# 8    9    Hamburger SV    34        € 658,231 (£ 551,932, $670,811)
# 9   10       Stuttgart    34        € 562,923 (£ 472,016, $573,682)
# 10  11            Köln    38        € 562,635 (£ 471,774, $573,387)
# 11  12   Werder Bremen    33        € 524,308 (£ 439,636, $534,328)
# 12  13  Eint Frankfurt    36        € 495,462 (£ 415,449, $504,931)
# ...

# %%
table_2 = pd.read_html('https://fbref.com/en/comps/20/2018-2019/wages/2018-2019-Bundesliga-Wages')
Bundes_Wages1819 = pd.DataFrame(table_2[0])
Bundes_Wages1819
# Out:
#     Rk           Squad  # Pl                           Weekly Wages  \
# 0    1   Bayern Munich    78  € 3,730,731 (£ 3,128,249, $3,802,031)
# 1    2        Dortmund    86  € 1,856,808 (£ 1,556,949, $1,892,294)
# 2    3      Schalke 04    93  € 1,345,654 (£ 1,128,342, $1,371,372)
# 3    4       Wolfsburg    98  € 1,261,494 (£ 1,057,773, $1,285,604)
# 4    5      Leverkusen    82  € 1,194,356 (£ 1,001,477, $1,217,182)
# 5    6      RB Leipzig    84    € 1,052,471 (£ 882,506, $1,072,586)
# 6    7      M'Gladbach    92        € 872,260 (£ 731,397, $888,930)
# 7    8  Eint Frankfurt   116        € 732,365 (£ 614,095, $746,362)
# 8    9      Hoffenheim    92        € 728,731 (£ 611,047, $742,658)
# 9   10       Stuttgart    86        € 699,190 (£ 586,277, $712,553)
# 10  11   Werder Bremen    94        € 676,038 (£ 566,864, $688,959)
# 11  12      Hertha BSC   101        € 601,702 (£ 504,532, $613,202)
# 12  13        Augsburg   101        € 459,529 (£ 385,319, $468,311)
# ...

# %%
table_3 = pd.read_html('https://fbref.com/en/comps/20/2019-2020/wages/2019-2020-Bundesliga-Wages')
Bundes_Wages1920 = pd.DataFrame(table_3[0])
Bundes_Wages1920
# Out:
#     Rk           Squad  # Pl                           Weekly Wages  \
# 0    1   Bayern Munich    76  € 4,117,692 (£ 3,452,719, $4,196,388)
# 1    2        Dortmund    80  € 2,054,231 (£ 1,722,490, $2,093,491)
# 2    3      RB Leipzig   102  € 1,360,385 (£ 1,140,694, $1,386,384)
# 3    4       Wolfsburg    82  € 1,285,962 (£ 1,078,290, $1,310,538)
# 4    5      M'Gladbach    84    € 1,039,423 (£ 871,565, $1,059,288)
# 5    6      Hertha BSC    97        € 970,577 (£ 813,837, $989,126)
# 6    7      Schalke 04    80        € 935,192 (£ 784,167, $953,065)
# 7    8      Leverkusen    74        € 919,615 (£ 771,105, $937,191)
# 8    9      Hoffenheim    86        € 916,346 (£ 768,364, $933,859)
# 9   10  Eint Frankfurt    94        € 828,269 (£ 694,511, $844,099)
# 10  11   Werder Bremen    88        € 818,077 (£ 685,964, $833,712)
# 11  12            Köln    87        € 748,654 (£ 627,753, $762,962)
# 12  13        Augsburg   100        € 536,154 (£ 449,570, $546,401)
# ...

# %%
table_4 = pd.read_html('https://fbref.com/en/comps/20/2020-2021/wages/2020-2021-Bundesliga-Wages')
Bundes_Wages2021 = pd.DataFrame(table_4[0])
Bundes_Wages2021
# Out:
#     Rk           Squad  # Pl                           Weekly Wages  \
# 0    1   Bayern Munich    83  € 4,318,654 (£ 3,621,227, $4,401,191)
# 1    2        Dortmund    85  € 1,737,115 (£ 1,456,586, $1,770,315)
# 2    3      Schalke 04    93  € 1,202,308 (£ 1,008,145, $1,225,286)
# 3    4       Wolfsburg    82    € 1,112,885 (£ 933,163, $1,134,154)
# 4    5      Leverkusen    85    € 1,080,769 (£ 906,234, $1,101,425)
# 5    6      RB Leipzig    81    € 1,035,962 (£ 868,662, $1,055,761)
# 6    7      M'Gladbach    95        € 951,538 (£ 797,873, $969,724)
# 7    8  Eint Frankfurt    91        € 916,923 (£ 768,848, $934,447)
# 8    9      Hoffenheim    94        € 824,423 (£ 691,286, $840,179)
# 9   10      Hertha BSC    82        € 795,000 (£ 666,614, $810,194)
# 10  11            Köln    94        € 576,346 (£ 483,271, $587,361)
# 11  12   Werder Bremen    78        € 575,000 (£ 482,142, $585,989)
# 12  13        Mainz 05    90        € 445,769 (£ 373,781, $454,289)
# ...

# %%
table_5 = pd.read_html('https://fbref.com/en/comps/20/2021-2022/wages/2021-2022-Bundesliga-Wages')
Bundes_Wages2122 = pd.DataFrame(table_5[0])
Bundes_Wages2122
# Out:
#     Rk           Squad  # Pl                           Weekly Wages  \
# 0    1   Bayern Munich    79  € 4,588,654 (£ 3,847,625, $4,676,351)
# 1    2        Dortmund    95  € 1,735,962 (£ 1,455,618, $1,769,139)
# 2    3       Wolfsburg    93    € 1,183,269 (£ 992,181, $1,205,883)
# 3    4      RB Leipzig    85    € 1,038,846 (£ 871,081, $1,058,700)
# 4    5      Leverkusen    84      € 995,962 (£ 835,122, $1,014,996)
# 5    6      M'Gladbach    80        € 909,231 (£ 762,398, $926,608)
# 6    7      Hoffenheim    96        € 774,423 (£ 649,360, $789,224)
# 7    8      Hertha BSC    91        € 720,385 (£ 604,049, $734,152)
# 8    9  Eint Frankfurt    97        € 692,500 (£ 580,667, $705,735)
# 9   10            Köln    90        € 556,538 (£ 466,662, $567,175)
# 10  11        Augsburg    86        € 461,538 (£ 387,004, $470,359)
# 11  12    Union Berlin    90        € 412,500 (£ 345,885, $420,384)
# 12  13        Mainz 05    81        € 330,385 (£ 277,030, $336,699)
# ...

# %%
combined_bundesliga_wages = pd.concat([Bundes_Wages1718,
                                      Bundes_Wages1819,
                                      Bundes_Wages1920,
                                      Bundes_Wages2021,
                                      Bundes_Wages2122])
combined_bundesliga_wages.sample(10)
# Out:
#     Rk           Squad  # Pl                           Weekly Wages  \
# 0    1   Bayern Munich    38  € 3,491,942 (£ 2,928,023, $3,558,679)
# 6    7      M'Gladbach    95        € 951,538 (£ 797,873, $969,724)
# 4    5      Leverkusen    85    € 1,080,769 (£ 906,234, $1,101,425)
# 2    3      Schalke 04    93  € 1,202,308 (£ 1,008,145, $1,225,286)
# 10  11   Werder Bremen    94        € 676,038 (£ 566,864, $688,959)
# 8    9  Eint Frankfurt    97        € 692,500 (£ 580,667, $705,735)
# 13  14        Mainz 05    96        € 412,394 (£ 345,796, $420,276)
# 9   10      Hertha BSC    82        € 795,000 (£ 666,614, $810,194)
# 9   10            Köln    90        € 556,538 (£ 466,662, $567,175)
# 12  13        Augsburg   101        € 459,529 (£ 385,319, $468,311)
#
#                                    Annual Wages % Estimated
# 0   € 181,581,000 (£ 152,257,190, $185,051,324)        100%
# 6      € 49,480,000 (£ 41,489,393, $50,425,646)         78%
# ...
